# %%
# %%capture
# !pip install gym_super_mario_bros

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# ROOT = "/content/drive/My Drive/Practice/RL/DQN"

# %%
import os
import cv2
import gym
import time
import collections

import numpy as np
import torch as T
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm

import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %matplotlib inline

# %%
# T.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %% [markdown]
# ## **Wrappers**

# %%
# PREPROCESS EACH FRAME
class PreprocessFrames(gym.ObservationWrapper):
    """
    PREPROCESSES EACH FRAME (input = (rows, columns, 3)) [0-255]
    1. resize image                             -   (new_rows, new_columns, 1)       [0-255]
    2. convert to nparray                       -   array(new_rows, new_columns, )  [0-255]
    3. move axis(reshape)                       -   array(1, new_rows, new_columns)  [0-255]
    3. scale values from 0-1                    -   array(1, new_rows, new_columns)  [0.0-1.0]
    """
    def __init__(self, env, new_observation_shape):
        super().__init__(env)
        self.new_observation_shape = new_observation_shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=self.new_observation_shape, dtype=np.float32)
    
    def observation(self, observation):
        temp_frame = cv2.cvtColor(observation, cv2.COLOR_RGB2GRAY)
        temp_frame = cv2.resize(temp_frame, self.new_observation_shape[1:], interpolation=cv2.INTER_AREA)
        new_observation = np.array(temp_frame, dtype=np.float32).reshape(self.new_observation_shape)
        new_observation = new_observation / 255.0 
        return new_observation

# TO BE CALLED ON EACH SINGLE IMAGE (AFTER PREPROCESS)
class CustomStep(gym.Wrapper):
    """
    OVERRIDES step() & reset()
    1. repeats same action in 'n' skipped frames to compute faster.
    2. takes maximum of 2 frames.
    """
    def __init__(self, env, frame_skip):
        super().__init__(env)
        self.frame_skip = frame_skip
        self.observation_shape = env.observation_space.shape
        self.observation_buffer = np.zeros_like((2, self.observation_shape))

    def reset(self):
        observation = self.env.reset()
        self.observation_buffer = np.zeros_like((2, self.observation_shape))
        self.observation_buffer[0] = observation
        return observation

    # RETURN FRAME_SKIPPED FRAMES
    def step(self, action):
        total_reward = 0.0
        done = False

        for frame in range(self.frame_skip):
            observation, reward, done, info = self.env.step(action)
            total_reward += reward

            idx = frame % 2
            self.observation_buffer[idx] = observation

            if done: break

        observation_max = np.maximum(self.observation_buffer[0], self.observation_buffer[1])
        return observation_max, total_reward, done, info


# STACK OBSERVATIONS
class StackFrames(gym.ObservationWrapper):
    """
    STACKS stack_size FRAMES TOGETHER AND RETURNS AS THE 'observation'
    1. on reset() returns first 'observation' STACKED 'stack_size' times
    2. observation() returns current 'observation' STACKED with 'stack_size-1' previous 'observation'
    """
    def __init__(self, env, stack_size):
        super().__init__(env)
        self.observation_space = gym.spaces.Box(
                                    env.observation_space.low.repeat(stack_size, axis=0),
                                    env.observation_space.high.repeat(stack_size, axis=0)
                                 )
        self.stack = collections.deque(maxlen=stack_size)

    def reset(self):
        self.stack.clear()
        observation = self.env.reset()
        for _ in range(self.stack.maxlen):
            self.stack.append(observation)
        observation = np.array(self.stack).reshape(self.observation_space.shape)
        return observation
        
    def observation(self, observation):
        self.stack.append(observation)
        observation = np.array(self.stack).reshape(self.observation_space.shape)
        return observation

class CustomReward(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self._current_score = 0

    def step(self, action):
        observation, reward, done, info = self.env.step(action)
        reward += (info['score'] - self._current_score) / 40.0
        self._current_score = info['score']
        if done:
            if info['flag_get']:
                reward += 350.0
            else:
                reward -= 50.0
        return observation, reward / 10.0, done, info

# %%
# TIE EVERYTHING TOGETHER
def make_env(env_name, new_observation_shape=(1,96,96), stack_size=4, frame_skip=4):
    env = gym.make(env_name)
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = PreprocessFrames(env, new_observation_shape=new_observation_shape)
    env = CustomStep(env, frame_skip=4)
    env = StackFrames(env, stack_size=stack_size)
    env = CustomReward(env)
    return env

# %% [markdown]
# ## **ReplayBuffer**

# %%
class ReplayBuffer:
    def __init__(self, mem_size, observation_shape, n_actions, alpha):
        self.mem_size = mem_size
        self.mem_counter = 0
        self.ALPHA = alpha
        # DATA
        self.states = np.zeros((mem_size, *observation_shape), dtype=np.float32)
        self.actions = np.zeros(mem_size, dtype=np.int64)
        self.rewards = np.zeros(mem_size, dtype=np.int64)
        self.states_ = np.zeros((mem_size, *observation_shape), dtype=np.float32)
        self.terminals = np.zeros(mem_size, dtype=bool)
        self.priorities = np.zeros(mem_size, dtype=np.float32)

    # STORE TRANSITIONS IN BUFFER
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_counter % self.mem_size
        self.states[index] = state
        self.actions[index] = action
        self.rewards[index] = reward
        self.states_[index] = state_
        self.terminals[index] = done    # 1 if 'done' else 0
        self.priorities[index] = self.priorities.max() if (self.mem_counter>0) else 1.0
        self.mem_counter += 1
    
    # UPDATE PRIORITIES LIST
    def update_priotities(self, indices, errors, offset):
        priorities = abs(errors) + offset
        self.priorities[indices] = priorities

    # UNIFORMLY SAMPLES 'BUFFER' AND RETURNS A 'BATCH' OF batch_size
    def sample_batch(self, batch_size, beta):
        max_index = min(self.mem_counter, self.mem_size) 
        priorities = self.priorities[:max_index]
        probabilities = (priorities ** self.ALPHA) / ((priorities ** self.ALPHA).sum())  # Pr = pi^a/P^a
        batch_indices = np.random.choice(max_index, batch_size, p=probabilities)

        importance = (max_index * probabilities[batch_indices]) ** (-beta)               # (1/N * 1/Pr)^b
        importance = importance / importance.max()
        importance = np.array(importance, dtype=np.float32)

        states = self.states[batch_indices]
        actions = self.actions[batch_indices]
        rewards = self.rewards[batch_indices]
        states_ = self.states_[batch_indices]
        terminals = self.terminals[batch_indices]
        return (batch_indices, states, actions, rewards, states_, terminals, importance)

# %% [markdown]
# ## **Network**

# %%
class DuelingDeepQNetwork(nn.Module):
    def __init__(self, lr, observation_shape, n_actions, model_name, model_dir):
        super().__init__()
        self.model_dir = model_dir
        self.model_file = os.path.join(self.model_dir, model_name)
        # CNN
        self.conv1 = nn.Conv2d(observation_shape[0], 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        # CNN -> ANN
        fc_input_dims = self.caculate_conv_output_dims(observation_shape)
        # ANN
        self.fc1 = nn.Linear(fc_input_dims, 512)
        # DUELING
        self.V = nn.Linear(512, 1)
        self.A = nn.Linear(512, n_actions)
        # UTILS
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)
        self.loss = nn.SmoothL1Loss() # CUSTOM LOSS IN AGENT
        self.to(self.device)
    
    def forward(self, state):
        t = F.relu(self.conv1(state))
        t = F.relu(self.conv2(t))
        t = F.relu(self.conv3(t))
        t = F.relu(self.fc1(t.reshape(t.shape[0], -1)))
        V = self.V(t)
        A = self.A(t)
        return V,A

    def caculate_conv_output_dims(self, observation_shape):
        dims = T.zeros((1, *observation_shape))
        dims = self.conv1(dims)
        dims = self.conv2(dims)
        dims = self.conv3(dims)
        return int(np.prod(dims.shape))

    def save_model(self):
        print("[INFO] Saving model")
        checkpoint = {
            'model_state_dict': self.state_dict(),
            'optimizer_state_dict' : self.optimizer.state_dict()
        }
        T.save(checkpoint, self.model_file)
    
    def load_model(self, cpu=False):
        print("[INFO] Loading model")
        
        map_location = T.device('cpu') if (cpu) else None
        
        checkpoint = T.load(self.model_file, map_location=map_location)
        self.load_state_dict(checkpoint['model_state_dict'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %% [markdown]
# ## **Agent**

# %%
class DuelingDDQNAgent:
    def __init__(self, observation_shape, n_actions, lr, gamma, epsilon, epsilon_min, epsilon_decay, beta, beta_max, beta_increment,
                 mem_size, mem_alpha, batch_size, Q_TARGET_replace_interval, initial_exploration_steps, algo_name, env_name, model_dir):
        self.observation_shape = observation_shape
        self.n_actions = n_actions
        self.LR = lr
        self.GAMMA = gamma
        self.EPSILON = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.BETA = beta
        self.beta_max = beta_max
        self.beta_increment = beta_increment

        # MEM PARAMS
        self.mem_size = mem_size
        self.batch_size = batch_size
        self.memory = ReplayBuffer(mem_size, observation_shape, n_actions, mem_alpha)

        # MODEL PARAMS
        self.initial_exploration_steps = initial_exploration_steps
        self.exploration_counter = 0
        self.learn_counter = 0 # TO UPDATE TARGET NETWORK
        self.algo_name = algo_name
        self.env_name = env_name
        self.model_dir = model_dir
        self.Q_TARGET_replace_interval = Q_TARGET_replace_interval
        # Q1
        self.Q_STEP = DuelingDeepQNetwork(lr, observation_shape, n_actions,
                              model_name = env_name+'_'+algo_name+'_Q_STEP',
                              model_dir = model_dir)
        # Q2
        self.Q_TARGET = DuelingDeepQNetwork(lr, observation_shape, n_actions,
                              model_name = env_name+'_'+algo_name+'_Q_TARGET',
                              model_dir = model_dir)

    # e-GREEDY POLICY
    def get_action(self, observation, greedy=False):
        if ( (np.random.uniform() >= self.EPSILON) or greedy):
            observation = T.tensor(observation, dtype=T.float32).to(self.Q_STEP.device)
            state = T.unsqueeze(observation, 0)
            _,A = self.Q_STEP(state)
            action = T.argmax(A).item()
        else:
            action = env.action_space.sample()
        return action

    def learn(self):
        if (self.exploration_counter < self.initial_exploration_steps): return # return if not explored enough
        if (self.memory.mem_counter < self.batch_size): return # return if insufficient samples present
        # RESET TARGET NETWORK (every 1000 steps)
        self.update_Q_TARGET()

        batch_indices, states, actions, rewards, states_, terminals, importance = self.sample_batch()
        # PREDICT Q1(s,a)
        v1,a1 = self.Q_STEP(states)
        q1 = v1 + (a1 - a1.mean(dim=1, keepdim=True)) # q - batch_size * n_actions
        indices = np.arange(len(actions))
        q1_preds = q1[indices,actions]

        # GET V1,A2(s_,A) and V2,A2(s_,A)
        v1_, a1_ = self.Q_STEP(states_)
        v2_, a2_ = self.Q_TARGET(states_)
        # GET Q1(s_,A) and Q2(s_,A)
        q1_ = v1_ + (a1_ - a1_.mean(dim=1, keepdim=True))
        q2_ = v2_ + (a2_ - a2_.mean(dim=1, keepdim=True))
        # argmax(Q1(s_,A)) - (max)a_
        # Q2(s_, (max)a_) - TARGETS
        a_ = T.argmax(q1_, dim=1)
        indices = np.arange(len(a_))
        q2_next = q2_[indices, a_]
        q2_next[terminals] = 0.0                      # Q2(s_) = 0 where terminal=1
        q2_targets = rewards + (self.GAMMA * q2_next)

        # CALC LOSS & BACKPROP
        # errors = (q1_preds - q2_targets)
        # loss = ((errors ** 2) * importance)
        errors = self.Q_TARGET.loss(q1_preds, q2_targets)
        loss = errors * importance
        loss = loss.mean()

        self.Q_STEP.optimizer.zero_grad()
        loss.backward()
        self.Q_STEP.optimizer.step()

        self.learn_counter += 1
        self.decay_epsilon()
        self.increment_beta()
        self.memory.update_priotities(batch_indices, errors.cpu().detach().numpy(), offset=0.1)

    def update_Q_TARGET(self):
        if ((self.learn_counter % self.Q_TARGET_replace_interval) == 0):
            self.Q_TARGET.load_state_dict(self.Q_STEP.state_dict())
    
    def decay_epsilon(self):
        if (self.EPSILON > self.epsilon_min):
            self.EPSILON -= self.epsilon_decay
        else:
            self.EPSILON = self.epsilon_min

    def increment_beta(self):
        if(self.BETA < self.beta_max):
            self.BETA += self.beta_increment
        else:
            self.BETA = self.beta_max
    
    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_batch(self):
        batch_indices, states, actions, rewards, states_, terminals, importance = self.memory.sample_batch(self.batch_size, self.BETA)
        states = T.tensor(states).to(self.Q_STEP.device)
        actions = T.tensor(actions).to(self.Q_STEP.device)
        rewards = T.tensor(rewards).to(self.Q_STEP.device)
        states_ = T.tensor(states_).to(self.Q_STEP.device)
        terminals = T.tensor(terminals).to(self.Q_STEP.device)
        importance = T.tensor(importance).to(self.Q_STEP.device)
        return batch_indices, states, actions, rewards, states_, terminals, importance
        
    def save_models(self):
        self.Q_STEP.save_model()
        self.Q_TARGET.save_model()
    
    def load_models(self, cpu=False):
        self.Q_STEP.load_model(cpu)
        self.Q_TARGET.load_model(cpu)

# %% [markdown]
# ## **Training**

# %%
env_name = 'SuperMarioBros-1-1-v0'
env = make_env(env_name)

# SIMPLE_MOVEMENT = [
#     ['NOOP'],
#     ['right'],
#     ['right', 'A'],
#     ['right', 'B'],
#     ['right', 'A', 'B'],
#     ['A'],
#     ['left'],
# ]

# %%
agent = DuelingDDQNAgent(observation_shape=env.observation_space.shape,
                         n_actions=env.action_space.n,
                         lr=1e-4,
                         gamma=0.99,
                         epsilon=1.0,
                         epsilon_min=0.01,
                         epsilon_decay=1e-6,
                         beta=0.4,
                         beta_max=1.0,
                         beta_increment=6e-5,
                         mem_size=20000,
                         mem_alpha=0.6,
                         batch_size=32,
                         Q_TARGET_replace_interval=1000,
                         initial_exploration_steps = 10000,
                         algo_name='DuelingDDQN',
                         env_name=env_name,
                         model_dir=ROOT)

# %%
## IF NEW TRAIN CYCLE
N_EPISODES = 10000

best_reward = -np.inf
episode_rewards, episode_lengths, episode_epsilons, mean_rewards = [],[],[],[]

# ## IF SERIALIZED OBJECT EXISTS
# train_metadata = T.load((ROOT+"/train_metadata.pkl"))

# N_EPISODES = 5000 - train_metadata["episode_n"]
# best_reward = train_metadata["best_reward"]
# episode_rewards = train_metadata["episode_rewards"]
# episode_lengths = train_metadata["episode_lengths"]
# episode_epsilons = train_metadata["episode_epsilons"]
# mean_rewards = train_metadata["mean_rewards"]

# agent.EPSILON = episode_epsilons[len(episode_epsilons)-1]
# agent.load_models()

# %%
for episode_n in tqdm(range(N_EPISODES)):
    total_reward, total_moves = 0,0

    done = False
    observation = env.reset()

    while not done:
        agent.exploration_counter += 1
        # e-GREEDY ACTION
        action = agent.get_action(observation)
        observation_, reward, done, _ = env.step(action)

        total_reward += reward
        total_moves += 1

        # STORE DATA & LEARN
        agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()

        observation = observation_

    episode_rewards.append(total_reward)
    episode_lengths.append(total_moves)
    episode_epsilons.append(agent.EPSILON)

    mean_reward = np.mean(episode_rewards[-100:])
    mean_rewards.append(mean_reward)
    
    if(mean_reward > best_reward):
        agent.save_models()
        best_reward = mean_reward

        train_metadata = {
            'episode_n': episode_n,
            'best_reward': best_reward,
            'mean_rewards': mean_rewards,
            'episode_rewards': episode_rewards, 
            'episode_lengths': episode_lengths,
            'episode_epsilons': episode_epsilons
        }
        T.save(train_metadata, (ROOT+"/train_metadata.pkl"))

    print("ITER: ",episode_n,"\tRWD: ",round(total_reward,2),"\tM_RWD: ",round(mean_reward,2),"\tLEN: ",total_moves,"\tEPS: ",round(agent.EPSILON,4))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# [INFO] Saving model
# [INFO] Saving model
# ITER:  0 	RWD:  54.35 	M_RWD:  54.35 	LEN:  727 	EPS:  1.0
# [INFO] Saving model
# [INFO] Saving model
# ITER:  1 	RWD:  65.35 	M_RWD:  59.85 	LEN:  354 	EPS:  1.0
# ITER:  2 	RWD:  53.2 	M_RWD:  57.63 	LEN:  157 	EPS:  1.0
# ITER:  3 	RWD:  18.1 	M_RWD:  47.75 	LEN:  44 	EPS:  1.0
# ITER:  4 	RWD:  18.4 	M_RWD:  41.88 	LEN:  42 	EPS:  1.0
# ITER:  5 	RWD:  55.15 	M_RWD:  44.09 	LEN:  108 	EPS:  1.0
# ITER:  6 	RWD:  67.85 	M_RWD:  47.49 	LEN:  409 	EPS:  1.0
# ITER:  7 	RWD:  71.9 	M_RWD:  50.54 	LEN:  322 	EPS:  1.0
# ITER:  8 	RWD:  18.5 	M_RWD:  46.98 	LEN:  44 	EPS:  1.0
# ITER:  9 	RWD:  14.9 	M_RWD:  43.77 	LEN:  59 	EPS:  1.0
# ITER:  10 	RWD:  66.85 	M_RWD:  45.87 	LEN:  629 	EPS:  1.0
# ITER:  11 	RWD:  68.5 	M_RWD:  47.75 	LEN:  544 	EPS:  1.0
# ITER:  12 	RWD:  52.85 	M_RWD:  48.15 	LEN:  1128 	EPS:  1.0
# ITER:  13 	RWD:  68.35 	M_RWD:  49.59 	LEN:  152 	EPS:  1.0
# ITER:  14 	RWD:  74.75 	M_RWD:  51.27 	LEN:  266 	EPS:  1.0
# ITER:  15 	RWD:  53.05 	M_RWD:  51.38 	LEN:  998 	EPS:  1.0
# ITER:  16 	RWD:  13.45 	M_RWD:  49.15 	LEN:  66 	EPS:  1.0
# ITER:  17 	RWD:  14.6 	M_RWD:  47.23 	LEN:  54 	EPS:  1.0
# ITER:  18 	RWD:  58.95 	M_RWD:  47.84 	LEN:  152 	EPS:  1.0
# ITER:  19 	RWD:  53.45 	M_RWD:  48.13 	LEN:  874 	EPS:  1.0
# ITER:  20 	RWD:  18.1 	M_RWD:  46.7 	LEN:  40 	EPS:  1.0
# ITER:  21 	RWD:  66.8 	M_RWD:  47.61 	LEN:  654 	EPS:  1.0
# ITER:  22 	RWD:  58.75 	M_RWD:  48.09 	LEN:  154 	EPS:  1.0
# ITER:  23 	RWD:  57.8 	M_RWD:  48.5 	LEN:  196 	EPS:  1.0
# ITER:  24 	RWD:  57.5 	M_RWD:  48.86 	LEN:  90 	EPS:  1.0
# ITER:  25 	RWD:  71.2 	M_RWD:  49.72 	LEN:  296 	EPS:  1.0
# ITER:  26 	RWD:  92.0 	M_RWD:  51.28 	LEN:  499 	EPS:  1.0
# ITER:  27 	RWD:  51.25 	M_RWD:  51.28 	LEN:  190 	EPS:  1.0
# ITER:  28 	RWD:  60.4 	M_RWD:  51.6 	LEN:  618 	EPS:  1.0
# ITER:  29 	RWD:  54.65 	M_RWD:  51.7 	LEN:  115 	EPS:  1.0
# ITER:  30 	RWD:  19.25 	M_RWD:  50.65 	LEN:  47 	EPS:  1.0
# ITER:  31 	RWD:  62.75 	M_RWD:  51.03 	LEN:  861 	EPS:  0.9991
# ITER:  32 	RWD:  75.4 	M_RWD:  51.77 	LEN:  1314 	EPS:  0.9978
# ITER:  33 	RWD:  53.9 	M_RWD:  51.83 	LEN:  129 	EPS:  0.9977
# ITER:  34 	RWD:  18.15 	M_RWD:  50.87 	LEN:  44 	EPS:  0.9976
# ITER:  35 	RWD:  52.8 	M_RWD:  50.92 	LEN:  180 	EPS:  0.9974
# ITER:  36 	RWD:  40.55 	M_RWD:  50.64 	LEN:  2005 	EPS:  0.9954
# ITER:  37 	RWD:  65.2 	M_RWD:  51.03 	LEN:  451 	EPS:  0.995
# ITER:  38 	RWD:  60.0 	M_RWD:  51.26 	LEN:  88 	EPS:  0.9949
# ITER:  39 	RWD:  54.55 	M_RWD:  51.34 	LEN:  133 	EPS:  0.9948
# ITER:  40 	RWD:  100.35 	M_RWD:  52.53 	LEN:  1552 	EPS:  0.9932
# ITER:  41 	RWD:  90.1 	M_RWD:  53.43 	LEN:  611 	EPS:  0.9926
# ITER:  42 	RWD:  18.05 	M_RWD:  52.6 	LEN:  37 	EPS:  0.9926
# ITER:  43 	RWD:  56.45 	M_RWD:  52.69 	LEN:  182 	EPS:  0.9924
# ITER:  44 	RWD:  68.7 	M_RWD:  53.05 	LEN:  508 	EPS:  0.9919
# ITER:  45 	RWD:  16.75 	M_RWD:  52.26 	LEN:  41 	EPS:  0.9918
# ITER:  46 	RWD:  18.5 	M_RWD:  51.54 	LEN:  46 	EPS:  0.9918
# ITER:  47 	RWD:  127.85 	M_RWD:  53.13 	LEN:  730 	EPS:  0.9911
# ITER:  48 	RWD:  17.75 	M_RWD:  52.41 	LEN:  41 	EPS:  0.991
# ITER:  49 	RWD:  39.0 	M_RWD:  52.14 	LEN:  2005 	EPS:  0.989
# ITER:  50 	RWD:  18.5 	M_RWD:  51.48 	LEN:  40 	EPS:  0.989
# ITER:  51 	RWD:  17.5 	M_RWD:  50.83 	LEN:  56 	EPS:  0.9889
# ITER:  52 	RWD:  71.0 	M_RWD:  51.21 	LEN:  469 	EPS:  0.9884
# ITER:  53 	RWD:  54.3 	M_RWD:  51.26 	LEN:  137 	EPS:  0.9883
# ITER:  54 	RWD:  16.6 	M_RWD:  50.63 	LEN:  48 	EPS:  0.9883
# ITER:  55 	RWD:  58.4 	M_RWD:  50.77 	LEN:  103 	EPS:  0.9882
# ITER:  56 	RWD:  51.6 	M_RWD:  50.79 	LEN:  380 	EPS:  0.9878
# ITER:  57 	RWD:  51.2 	M_RWD:  50.79 	LEN:  262 	EPS:  0.9875
# ITER:  58 	RWD:  111.9 	M_RWD:  51.83 	LEN:  994 	EPS:  0.9865
# ITER:  59 	RWD:  52.55 	M_RWD:  51.84 	LEN:  119 	EPS:  0.9864
# ITER:  60 	RWD:  61.15 	M_RWD:  52.0 	LEN:  922 	EPS:  0.9855
# ITER:  61 	RWD:  172.3 	M_RWD:  53.94 	LEN:  682 	EPS:  0.9848
# ITER:  62 	RWD:  38.55 	M_RWD:  53.69 	LEN:  2005 	EPS:  0.9828
# ITER:  63 	RWD:  52.45 	M_RWD:  53.67 	LEN:  1068 	EPS:  0.9817
# ITER:  64 	RWD:  19.5 	M_RWD:  53.15 	LEN:  43 	EPS:  0.9817
# ITER:  65 	RWD:  16.3 	M_RWD:  52.59 	LEN:  51 	EPS:  0.9816
# ITER:  66 	RWD:  58.45 	M_RWD:  52.68 	LEN:  154 	EPS:  0.9815
# ITER:  67 	RWD:  51.0 	M_RWD:  52.65 	LEN:  242 	EPS:  0.9812
# ITER:  68 	RWD:  58.05 	M_RWD:  52.73 	LEN:  141 	EPS:  0.9811
# ITER:  69 	RWD:  71.5 	M_RWD:  53.0 	LEN:  1582 	EPS:  0.9795
# ITER:  70 	RWD:  118.8 	M_RWD:  53.92 	LEN:  625 	EPS:  0.9789
# ITER:  71 	RWD:  55.0 	M_RWD:  53.94 	LEN:  121 	EPS:  0.9788
# ITER:  72 	RWD:  18.6 	M_RWD:  53.45 	LEN:  44 	EPS:  0.9787
# ITER:  73 	RWD:  81.65 	M_RWD:  53.84 	LEN:  1075 	EPS:  0.9776
# ITER:  74 	RWD:  62.65 	M_RWD:  53.95 	LEN:  416 	EPS:  0.9772
# ITER:  75 	RWD:  57.2 	M_RWD:  54.0 	LEN:  172 	EPS:  0.9771
# ITER:  76 	RWD:  57.55 	M_RWD:  54.04 	LEN:  114 	EPS:  0.9769
# ITER:  77 	RWD:  54.45 	M_RWD:  54.05 	LEN:  138 	EPS:  0.9768
# ITER:  78 	RWD:  76.05 	M_RWD:  54.33 	LEN:  1373 	EPS:  0.9754
# ITER:  79 	RWD:  73.1 	M_RWD:  54.56 	LEN:  308 	EPS:  0.9751
# ITER:  80 	RWD:  16.95 	M_RWD:  54.1 	LEN:  57 	EPS:  0.9751
# ITER:  81 	RWD:  96.35 	M_RWD:  54.61 	LEN:  340 	EPS:  0.9747
# ITER:  82 	RWD:  178.7 	M_RWD:  56.11 	LEN:  667 	EPS:  0.9741
# ITER:  83 	RWD:  50.15 	M_RWD:  56.04 	LEN:  121 	EPS:  0.9739
# ITER:  84 	RWD:  91.65 	M_RWD:  56.45 	LEN:  976 	EPS:  0.973
# ITER:  85 	RWD:  74.55 	M_RWD:  56.67 	LEN:  226 	EPS:  0.9727
# ITER:  86 	RWD:  51.85 	M_RWD:  56.61 	LEN:  224 	EPS:  0.9725
# ITER:  87 	RWD:  16.45 	M_RWD:  56.15 	LEN:  42 	EPS:  0.9725
# ITER:  88 	RWD:  57.95 	M_RWD:  56.17 	LEN:  101 	EPS:  0.9724
# ITER:  89 	RWD:  18.55 	M_RWD:  55.76 	LEN:  39 	EPS:  0.9723
# ITER:  90 	RWD:  67.6 	M_RWD:  55.89 	LEN:  446 	EPS:  0.9719
# ITER:  91 	RWD:  55.65 	M_RWD:  55.88 	LEN:  101 	EPS:  0.9718
# ITER:  92 	RWD:  15.25 	M_RWD:  55.45 	LEN:  57 	EPS:  0.9717
# ITER:  93 	RWD:  67.5 	M_RWD:  55.57 	LEN:  640 	EPS:  0.9711
# ITER:  94 	RWD:  19.0 	M_RWD:  55.19 	LEN:  38 	EPS:  0.9711
# ITER:  95 	RWD:  73.05 	M_RWD:  55.38 	LEN:  327 	EPS:  0.9707
# ITER:  96 	RWD:  56.35 	M_RWD:  55.39 	LEN:  195 	EPS:  0.9705
# ITER:  97 	RWD:  107.35 	M_RWD:  55.92 	LEN:  1203 	EPS:  0.9693
# ITER:  98 	RWD:  16.95 	M_RWD:  55.52 	LEN:  48 	EPS:  0.9693
# ITER:  99 	RWD:  55.9 	M_RWD:  55.53 	LEN:  122 	EPS:  0.9692
# ITER:  100 	RWD:  18.6 	M_RWD:  55.17 	LEN:  45 	EPS:  0.9691
# ITER:  101 	RWD:  51.1 	M_RWD:  55.03 	LEN:  205 	EPS:  0.9689
# ITER:  102 	RWD:  64.85 	M_RWD:  55.14 	LEN:  599 	EPS:  0.9683
# ITER:  103 	RWD:  16.05 	M_RWD:  55.12 	LEN:  53 	EPS:  0.9683
# ITER:  104 	RWD:  17.8 	M_RWD:  55.12 	LEN:  48 	EPS:  0.9682
# ITER:  105 	RWD:  90.4 	M_RWD:  55.47 	LEN:  590 	EPS:  0.9676
# ITER:  106 	RWD:  55.85 	M_RWD:  55.35 	LEN:  140 	EPS:  0.9675
# ITER:  107 	RWD:  16.55 	M_RWD:  54.8 	LEN:  53 	EPS:  0.9674
# ITER:  108 	RWD:  56.5 	M_RWD:  55.18 	LEN:  207 	EPS:  0.9672
# ITER:  109 	RWD:  55.95 	M_RWD:  55.59 	LEN:  89 	EPS:  0.9671
# ITER:  110 	RWD:  79.85 	M_RWD:  55.72 	LEN:  1160 	EPS:  0.966
# ITER:  111 	RWD:  55.4 	M_RWD:  55.58 	LEN:  244 	EPS:  0.9657
# ITER:  112 	RWD:  114.05 	M_RWD:  56.2 	LEN:  938 	EPS:  0.9648
# ITER:  113 	RWD:  70.05 	M_RWD:  56.21 	LEN:  268 	EPS:  0.9645
# ITER:  114 	RWD:  62.4 	M_RWD:  56.09 	LEN:  1975 	EPS:  0.9625
# ITER:  115 	RWD:  17.7 	M_RWD:  55.74 	LEN:  51 	EPS:  0.9625
# ITER:  116 	RWD:  56.3 	M_RWD:  56.17 	LEN:  180 	EPS:  0.9623
# ITER:  117 	RWD:  68.55 	M_RWD:  56.7 	LEN:  308 	EPS:  0.962
# ITER:  118 	RWD:  15.75 	M_RWD:  56.27 	LEN:  49 	EPS:  0.962
# ITER:  119 	RWD:  59.2 	M_RWD:  56.33 	LEN:  636 	EPS:  0.9613
# ITER:  120 	RWD:  74.25 	M_RWD:  56.89 	LEN:  268 	EPS:  0.9611
# ITER:  121 	RWD:  18.15 	M_RWD:  56.41 	LEN:  39 	EPS:  0.961
# ITER:  122 	RWD:  15.5 	M_RWD:  55.97 	LEN:  58 	EPS:  0.961
# ITER:  123 	RWD:  56.4 	M_RWD:  55.96 	LEN:  166 	EPS:  0.9608
# ITER:  124 	RWD:  53.35 	M_RWD:  55.92 	LEN:  186 	EPS:  0.9606
# ITER:  125 	RWD:  57.65 	M_RWD:  55.78 	LEN:  154 	EPS:  0.9604
# ITER:  126 	RWD:  110.1 	M_RWD:  55.96 	LEN:  1177 	EPS:  0.9593
# ITER:  127 	RWD:  57.3 	M_RWD:  56.02 	LEN:  143 	EPS:  0.9591
# ITER:  128 	RWD:  53.65 	M_RWD:  55.96 	LEN:  159 	EPS:  0.959
# ITER:  129 	RWD:  57.7 	M_RWD:  55.99 	LEN:  199 	EPS:  0.9588
# ITER:  130 	RWD:  53.9 	M_RWD:  56.33 	LEN:  100 	EPS:  0.9587
# ITER:  131 	RWD:  109.4 	M_RWD:  56.8 	LEN:  1179 	EPS:  0.9575
# ITER:  132 	RWD:  17.95 	M_RWD:  56.22 	LEN:  42 	EPS:  0.9575
# ITER:  133 	RWD:  93.8 	M_RWD:  56.62 	LEN:  505 	EPS:  0.9569
# ITER:  134 	RWD:  53.0 	M_RWD:  56.97 	LEN:  113 	EPS:  0.9568
# ITER:  135 	RWD:  57.15 	M_RWD:  57.02 	LEN:  215 	EPS:  0.9566
# ITER:  136 	RWD:  68.7 	M_RWD:  57.3 	LEN:  178 	EPS:  0.9564
# ITER:  137 	RWD:  57.65 	M_RWD:  57.22 	LEN:  169 	EPS:  0.9563
# ITER:  138 	RWD:  72.1 	M_RWD:  57.34 	LEN:  565 	EPS:  0.9557
# ITER:  139 	RWD:  53.05 	M_RWD:  57.33 	LEN:  93 	EPS:  0.9556
# ITER:  140 	RWD:  53.45 	M_RWD:  56.86 	LEN:  112 	EPS:  0.9555
# ITER:  141 	RWD:  15.1 	M_RWD:  56.11 	LEN:  63 	EPS:  0.9554
# ITER:  142 	RWD:  57.3 	M_RWD:  56.5 	LEN:  940 	EPS:  0.9545
# ITER:  143 	RWD:  57.15 	M_RWD:  56.51 	LEN:  111 	EPS:  0.9544
# ITER:  144 	RWD:  18.35 	M_RWD:  56.0 	LEN:  38 	EPS:  0.9543
# ITER:  145 	RWD:  68.75 	M_RWD:  56.52 	LEN:  351 	EPS:  0.954
# ITER:  146 	RWD:  66.15 	M_RWD:  57.0 	LEN:  418 	EPS:  0.9536
# ITER:  147 	RWD:  116.75 	M_RWD:  56.89 	LEN:  793 	EPS:  0.9528
# ITER:  148 	RWD:  18.15 	M_RWD:  56.89 	LEN:  31 	EPS:  0.9528
# ITER:  149 	RWD:  66.2 	M_RWD:  57.17 	LEN:  344 	EPS:  0.9524
# ITER:  150 	RWD:  107.3 	M_RWD:  58.05 	LEN:  1119 	EPS:  0.9513
# ITER:  151 	RWD:  18.9 	M_RWD:  58.07 	LEN:  38 	EPS:  0.9513
# ITER:  152 	RWD:  104.75 	M_RWD:  58.41 	LEN:  1248 	EPS:  0.95
# ITER:  153 	RWD:  16.45 	M_RWD:  58.03 	LEN:  40 	EPS:  0.95
# ITER:  154 	RWD:  94.4 	M_RWD:  58.81 	LEN:  460 	EPS:  0.9495
# ITER:  155 	RWD:  72.0 	M_RWD:  58.94 	LEN:  1503 	EPS:  0.948
# ITER:  156 	RWD:  15.5 	M_RWD:  58.58 	LEN:  51 	EPS:  0.948
# ITER:  157 	RWD:  124.2 	M_RWD:  59.31 	LEN:  351 	EPS:  0.9476
# ITER:  158 	RWD:  17.3 	M_RWD:  58.36 	LEN:  58 	EPS:  0.9475
# ITER:  159 	RWD:  73.05 	M_RWD:  58.57 	LEN:  148 	EPS:  0.9474
# ITER:  160 	RWD:  18.65 	M_RWD:  58.14 	LEN:  42 	EPS:  0.9474
# ITER:  161 	RWD:  67.05 	M_RWD:  57.09 	LEN:  135 	EPS:  0.9472
# ITER:  162 	RWD:  58.8 	M_RWD:  57.29 	LEN:  150 	EPS:  0.9471
# ITER:  163 	RWD:  119.35 	M_RWD:  57.96 	LEN:  699 	EPS:  0.9464
# ITER:  164 	RWD:  52.1 	M_RWD:  58.29 	LEN:  229 	EPS:  0.9461
# ITER:  165 	RWD:  100.0 	M_RWD:  59.13 	LEN:  589 	EPS:  0.9456
# ITER:  166 	RWD:  17.2 	M_RWD:  58.71 	LEN:  43 	EPS:  0.9455
# ITER:  167 	RWD:  53.65 	M_RWD:  58.74 	LEN:  132 	EPS:  0.9454
# ITER:  168 	RWD:  57.2 	M_RWD:  58.73 	LEN:  713 	EPS:  0.9447
# ITER:  169 	RWD:  70.15 	M_RWD:  58.72 	LEN:  418 	EPS:  0.9442
# ITER:  170 	RWD:  56.0 	M_RWD:  58.09 	LEN:  173 	EPS:  0.9441
# ITER:  171 	RWD:  54.3 	M_RWD:  58.08 	LEN:  974 	EPS:  0.9431
# ITER:  172 	RWD:  18.8 	M_RWD:  58.09 	LEN:  34 	EPS:  0.9431
# ITER:  173 	RWD:  143.65 	M_RWD:  58.71 	LEN:  1405 	EPS:  0.9417
# ITER:  174 	RWD:  84.0 	M_RWD:  58.92 	LEN:  788 	EPS:  0.9409
# ITER:  175 	RWD:  19.25 	M_RWD:  58.54 	LEN:  34 	EPS:  0.9408
# ITER:  176 	RWD:  67.3 	M_RWD:  58.64 	LEN:  146 	EPS:  0.9407
# ITER:  177 	RWD:  105.75 	M_RWD:  59.15 	LEN:  1333 	EPS:  0.9394
# ITER:  178 	RWD:  77.2 	M_RWD:  59.16 	LEN:  1236 	EPS:  0.9381
# ITER:  179 	RWD:  100.8 	M_RWD:  59.44 	LEN:  1607 	EPS:  0.9365
# [INFO] Saving model
# [INFO] Saving model
# ITER:  180 	RWD:  60.6 	M_RWD:  59.87 	LEN:  519 	EPS:  0.936
# ITER:  181 	RWD:  69.75 	M_RWD:  59.61 	LEN:  273 	EPS:  0.9357
# ITER:  182 	RWD:  17.9 	M_RWD:  58.0 	LEN:  40 	EPS:  0.9357
# ITER:  183 	RWD:  72.8 	M_RWD:  58.23 	LEN:  353 	EPS:  0.9353
# ITER:  184 	RWD:  116.5 	M_RWD:  58.48 	LEN:  665 	EPS:  0.9347
# ITER:  185 	RWD:  54.55 	M_RWD:  58.28 	LEN:  114 	EPS:  0.9346
# ITER:  186 	RWD:  81.6 	M_RWD:  58.57 	LEN:  1066 	EPS:  0.9335
# ITER:  187 	RWD:  75.65 	M_RWD:  59.17 	LEN:  149 	EPS:  0.9333
# ITER:  188 	RWD:  18.4 	M_RWD:  58.77 	LEN:  37 	EPS:  0.9333
# ITER:  189 	RWD:  54.75 	M_RWD:  59.13 	LEN:  126 	EPS:  0.9332
# ITER:  190 	RWD:  17.95 	M_RWD:  58.64 	LEN:  50 	EPS:  0.9331
# ITER:  191 	RWD:  94.0 	M_RWD:  59.02 	LEN:  1795 	EPS:  0.9313
# ITER:  192 	RWD:  92.9 	M_RWD:  59.8 	LEN:  466 	EPS:  0.9309
# ITER:  193 	RWD:  72.25 	M_RWD:  59.84 	LEN:  275 	EPS:  0.9306
# ITER:  194 	RWD:  14.35 	M_RWD:  59.8 	LEN:  58 	EPS:  0.9305
# [INFO] Saving model
# [INFO] Saving model
# ITER:  195 	RWD:  120.95 	M_RWD:  60.28 	LEN:  615 	EPS:  0.9299
# ITER:  196 	RWD:  51.85 	M_RWD:  60.23 	LEN:  157 	EPS:  0.9298
# ITER:  197 	RWD:  20.6 	M_RWD:  59.36 	LEN:  30 	EPS:  0.9297
# ITER:  198 	RWD:  73.7 	M_RWD:  59.93 	LEN:  307 	EPS:  0.9294
# ITER:  199 	RWD:  89.95 	M_RWD:  60.27 	LEN:  648 	EPS:  0.9288
# ITER:  200 	RWD:  17.25 	M_RWD:  60.26 	LEN:  43 	EPS:  0.9287
# ITER:  201 	RWD:  17.4 	M_RWD:  59.92 	LEN:  53 	EPS:  0.9287
# ITER:  202 	RWD:  16.7 	M_RWD:  59.44 	LEN:  52 	EPS:  0.9286
# ITER:  203 	RWD:  86.35 	M_RWD:  60.14 	LEN:  807 	EPS:  0.9278
# [INFO] Saving model
# [INFO] Saving model
# ITER:  204 	RWD:  54.25 	M_RWD:  60.51 	LEN:  166 	EPS:  0.9277
# ITER:  205 	RWD:  18.7 	M_RWD:  59.79 	LEN:  41 	EPS:  0.9276
# ITER:  206 	RWD:  55.35 	M_RWD:  59.78 	LEN:  770 	EPS:  0.9268
# ITER:  207 	RWD:  66.35 	M_RWD:  60.28 	LEN:  207 	EPS:  0.9266
# ITER:  208 	RWD:  53.5 	M_RWD:  60.25 	LEN:  214 	EPS:  0.9264
# [INFO] Saving model
# [INFO] Saving model
# ITER:  209 	RWD:  95.85 	M_RWD:  60.65 	LEN:  344 	EPS:  0.9261
# ITER:  210 	RWD:  79.1 	M_RWD:  60.64 	LEN:  1275 	EPS:  0.9248
# [INFO] Saving model
# [INFO] Saving model
# ITER:  211 	RWD:  57.5 	M_RWD:  60.66 	LEN:  160 	EPS:  0.9246
# ITER:  212 	RWD:  17.15 	M_RWD:  59.7 	LEN:  60 	EPS:  0.9246
# ITER:  213 	RWD:  56.0 	M_RWD:  59.56 	LEN:  106 	EPS:  0.9245
# ITER:  214 	RWD:  91.15 	M_RWD:  59.84 	LEN:  607 	EPS:  0.9239
# ITER:  215 	RWD:  67.9 	M_RWD:  60.34 	LEN:  539 	EPS:  0.9233
# ITER:  216 	RWD:  57.15 	M_RWD:  60.35 	LEN:  220 	EPS:  0.9231
# ITER:  217 	RWD:  72.75 	M_RWD:  60.4 	LEN:  311 	EPS:  0.9228
# [INFO] Saving model
# [INFO] Saving model
# ITER:  218 	RWD:  57.05 	M_RWD:  60.81 	LEN:  159 	EPS:  0.9226
# ITER:  219 	RWD:  16.7 	M_RWD:  60.38 	LEN:  47 	EPS:  0.9226
# ITER:  220 	RWD:  55.2 	M_RWD:  60.19 	LEN:  111 	EPS:  0.9225
# ITER:  221 	RWD:  17.2 	M_RWD:  60.18 	LEN:  46 	EPS:  0.9224
# ITER:  222 	RWD:  64.35 	M_RWD:  60.67 	LEN:  412 	EPS:  0.922
# ITER:  223 	RWD:  18.25 	M_RWD:  60.29 	LEN:  57 	EPS:  0.922
# ITER:  224 	RWD:  57.9 	M_RWD:  60.34 	LEN:  162 	EPS:  0.9218
# ITER:  225 	RWD:  54.85 	M_RWD:  60.31 	LEN:  168 	EPS:  0.9216
# ITER:  226 	RWD:  144.3 	M_RWD:  60.65 	LEN:  624 	EPS:  0.921
# [INFO] Saving model
# [INFO] Saving model
# ITER:  227 	RWD:  106.1 	M_RWD:  61.14 	LEN:  1256 	EPS:  0.9198
# ITER:  228 	RWD:  18.55 	M_RWD:  60.79 	LEN:  40 	EPS:  0.9197
# ITER:  229 	RWD:  76.7 	M_RWD:  60.98 	LEN:  158 	EPS:  0.9196
# ITER:  230 	RWD:  69.7 	M_RWD:  61.13 	LEN:  270 	EPS:  0.9193
# ITER:  231 	RWD:  91.25 	M_RWD:  60.95 	LEN:  600 	EPS:  0.9187
# [INFO] Saving model
# [INFO] Saving model
# ITER:  232 	RWD:  101.45 	M_RWD:  61.79 	LEN:  1437 	EPS:  0.9173
# ITER:  233 	RWD:  56.6 	M_RWD:  61.42 	LEN:  210 	EPS:  0.917
# ITER:  234 	RWD:  59.3 	M_RWD:  61.48 	LEN:  144 	EPS:  0.9169
# ITER:  235 	RWD:  60.0 	M_RWD:  61.51 	LEN:  539 	EPS:  0.9164
# ITER:  236 	RWD:  18.7 	M_RWD:  61.01 	LEN:  39 	EPS:  0.9163
# ITER:  237 	RWD:  119.45 	M_RWD:  61.63 	LEN:  735 	EPS:  0.9156
# ITER:  238 	RWD:  17.45 	M_RWD:  61.08 	LEN:  38 	EPS:  0.9155
# ITER:  239 	RWD:  57.95 	M_RWD:  61.13 	LEN:  205 	EPS:  0.9153
# [INFO] Saving model
# [INFO] Saving model
# ITER:  240 	RWD:  123.8 	M_RWD:  61.83 	LEN:  469 	EPS:  0.9149
# [INFO] Saving model
# [INFO] Saving model
# ITER:  241 	RWD:  52.35 	M_RWD:  62.2 	LEN:  165 	EPS:  0.9147
# [INFO] Saving model
# [INFO] Saving model
# ITER:  242 	RWD:  71.65 	M_RWD:  62.35 	LEN:  387 	EPS:  0.9143
# ITER:  243 	RWD:  52.85 	M_RWD:  62.3 	LEN:  100 	EPS:  0.9142
# [INFO] Saving model
# [INFO] Saving model
# ITER:  244 	RWD:  54.5 	M_RWD:  62.67 	LEN:  224 	EPS:  0.914
# ITER:  245 	RWD:  57.7 	M_RWD:  62.56 	LEN:  122 	EPS:  0.9139
# [INFO] Saving model
# [INFO] Saving model
# ITER:  246 	RWD:  98.9 	M_RWD:  62.88 	LEN:  264 	EPS:  0.9136
# ITER:  247 	RWD:  18.3 	M_RWD:  61.9 	LEN:  45 	EPS:  0.9136
# ITER:  248 	RWD:  53.15 	M_RWD:  62.25 	LEN:  264 	EPS:  0.9133
# ITER:  249 	RWD:  54.25 	M_RWD:  62.13 	LEN:  1017 	EPS:  0.9123
# ITER:  250 	RWD:  58.35 	M_RWD:  61.64 	LEN:  171 	EPS:  0.9121
# ITER:  251 	RWD:  16.75 	M_RWD:  61.62 	LEN:  49 	EPS:  0.9121
# ITER:  252 	RWD:  109.2 	M_RWD:  61.66 	LEN:  1193 	EPS:  0.9109
# ITER:  253 	RWD:  69.0 	M_RWD:  62.19 	LEN:  465 	EPS:  0.9104
# ITER:  254 	RWD:  17.1 	M_RWD:  61.42 	LEN:  44 	EPS:  0.9104
# ITER:  255 	RWD:  56.6 	M_RWD:  61.26 	LEN:  158 	EPS:  0.9102
# ITER:  256 	RWD:  16.7 	M_RWD:  61.27 	LEN:  59 	EPS:  0.9101
# ITER:  257 	RWD:  99.05 	M_RWD:  61.02 	LEN:  241 	EPS:  0.9099
# ITER:  258 	RWD:  12.85 	M_RWD:  60.98 	LEN:  75 	EPS:  0.9098
# ITER:  259 	RWD:  66.95 	M_RWD:  60.92 	LEN:  374 	EPS:  0.9095
# ITER:  260 	RWD:  18.55 	M_RWD:  60.92 	LEN:  40 	EPS:  0.9094
# ITER:  261 	RWD:  74.05 	M_RWD:  60.99 	LEN:  312 	EPS:  0.9091
# ITER:  262 	RWD:  17.85 	M_RWD:  60.58 	LEN:  44 	EPS:  0.9091
# ITER:  263 	RWD:  156.0 	M_RWD:  60.94 	LEN:  738 	EPS:  0.9083
# ITER:  264 	RWD:  50.3 	M_RWD:  60.92 	LEN:  124 	EPS:  0.9082
# ITER:  265 	RWD:  57.7 	M_RWD:  60.5 	LEN:  178 	EPS:  0.908
# ITER:  266 	RWD:  93.5 	M_RWD:  61.26 	LEN:  968 	EPS:  0.9071
# ITER:  267 	RWD:  84.85 	M_RWD:  61.58 	LEN:  806 	EPS:  0.9062
# ITER:  268 	RWD:  80.4 	M_RWD:  61.81 	LEN:  1142 	EPS:  0.9051
# ITER:  269 	RWD:  17.05 	M_RWD:  61.28 	LEN:  39 	EPS:  0.9051
# ITER:  270 	RWD:  19.2 	M_RWD:  60.91 	LEN:  41 	EPS:  0.905
# ITER:  271 	RWD:  58.2 	M_RWD:  60.95 	LEN:  107 	EPS:  0.9049
# ITER:  272 	RWD:  56.05 	M_RWD:  61.32 	LEN:  776 	EPS:  0.9041
# ITER:  273 	RWD:  118.45 	M_RWD:  61.07 	LEN:  746 	EPS:  0.9034
# ITER:  274 	RWD:  121.65 	M_RWD:  61.45 	LEN:  401 	EPS:  0.903
# ITER:  275 	RWD:  18.65 	M_RWD:  61.44 	LEN:  44 	EPS:  0.9029
# ITER:  276 	RWD:  57.6 	M_RWD:  61.34 	LEN:  209 	EPS:  0.9027
# ITER:  277 	RWD:  11.7 	M_RWD:  60.4 	LEN:  64 	EPS:  0.9027
# ITER:  278 	RWD:  121.1 	M_RWD:  60.84 	LEN:  545 	EPS:  0.9021
# ITER:  279 	RWD:  97.0 	M_RWD:  60.8 	LEN:  233 	EPS:  0.9019
# ITER:  280 	RWD:  16.8 	M_RWD:  60.36 	LEN:  51 	EPS:  0.9018
# ITER:  281 	RWD:  17.3 	M_RWD:  59.84 	LEN:  43 	EPS:  0.9018
# ITER:  282 	RWD:  51.35 	M_RWD:  60.17 	LEN:  997 	EPS:  0.9008
# ITER:  283 	RWD:  52.45 	M_RWD:  59.97 	LEN:  139 	EPS:  0.9007
# ITER:  284 	RWD:  88.1 	M_RWD:  59.69 	LEN:  838 	EPS:  0.8998
# ITER:  285 	RWD:  15.3 	M_RWD:  59.29 	LEN:  47 	EPS:  0.8998
# ITER:  286 	RWD:  119.1 	M_RWD:  59.67 	LEN:  589 	EPS:  0.8992
# ITER:  287 	RWD:  61.25 	M_RWD:  59.53 	LEN:  457 	EPS:  0.8987
# ITER:  288 	RWD:  16.55 	M_RWD:  59.51 	LEN:  78 	EPS:  0.8987
# ITER:  289 	RWD:  18.5 	M_RWD:  59.14 	LEN:  44 	EPS:  0.8986
# ITER:  290 	RWD:  19.8 	M_RWD:  59.16 	LEN:  38 	EPS:  0.8986
# ITER:  291 	RWD:  57.6 	M_RWD:  58.8 	LEN:  177 	EPS:  0.8984
# ITER:  292 	RWD:  40.8 	M_RWD:  58.28 	LEN:  2005 	EPS:  0.8964
# ITER:  293 	RWD:  93.3 	M_RWD:  58.49 	LEN:  389 	EPS:  0.896
# ITER:  294 	RWD:  16.1 	M_RWD:  58.51 	LEN:  51 	EPS:  0.896
# ITER:  295 	RWD:  15.1 	M_RWD:  57.45 	LEN:  54 	EPS:  0.8959
# ITER:  296 	RWD:  61.9 	M_RWD:  57.55 	LEN:  432 	EPS:  0.8955
# ITER:  297 	RWD:  55.6 	M_RWD:  57.9 	LEN:  132 	EPS:  0.8953
# ITER:  298 	RWD:  53.4 	M_RWD:  57.7 	LEN:  144 	EPS:  0.8952
# ITER:  299 	RWD:  18.4 	M_RWD:  56.98 	LEN:  48 	EPS:  0.8951
# ITER:  300 	RWD:  54.55 	M_RWD:  57.35 	LEN:  873 	EPS:  0.8943
# ITER:  301 	RWD:  19.85 	M_RWD:  57.38 	LEN:  54 	EPS:  0.8942
# ITER:  302 	RWD:  56.15 	M_RWD:  57.77 	LEN:  189 	EPS:  0.894
# ITER:  303 	RWD:  95.7 	M_RWD:  57.87 	LEN:  321 	EPS:  0.8937
# ITER:  304 	RWD:  56.25 	M_RWD:  57.89 	LEN:  193 	EPS:  0.8935
# ITER:  305 	RWD:  71.3 	M_RWD:  58.41 	LEN:  290 	EPS:  0.8932
# ITER:  306 	RWD:  17.7 	M_RWD:  58.03 	LEN:  47 	EPS:  0.8932
# ITER:  307 	RWD:  52.0 	M_RWD:  57.89 	LEN:  194 	EPS:  0.893
# ITER:  308 	RWD:  19.6 	M_RWD:  57.55 	LEN:  32 	EPS:  0.893
# ITER:  309 	RWD:  105.8 	M_RWD:  57.65 	LEN:  1250 	EPS:  0.8917
# ITER:  310 	RWD:  57.05 	M_RWD:  57.43 	LEN:  171 	EPS:  0.8915
# ITER:  311 	RWD:  18.65 	M_RWD:  57.04 	LEN:  37 	EPS:  0.8915
# ITER:  312 	RWD:  19.3 	M_RWD:  57.06 	LEN:  37 	EPS:  0.8915
# ITER:  313 	RWD:  52.3 	M_RWD:  57.03 	LEN:  1181 	EPS:  0.8903
# ITER:  314 	RWD:  61.7 	M_RWD:  56.73 	LEN:  473 	EPS:  0.8898
# ITER:  315 	RWD:  54.7 	M_RWD:  56.6 	LEN:  96 	EPS:  0.8897
# ITER:  316 	RWD:  16.6 	M_RWD:  56.2 	LEN:  50 	EPS:  0.8897
# ITER:  317 	RWD:  18.1 	M_RWD:  55.65 	LEN:  70 	EPS:  0.8896
# ITER:  318 	RWD:  18.7 	M_RWD:  55.27 	LEN:  55 	EPS:  0.8895
# ITER:  319 	RWD:  69.1 	M_RWD:  55.79 	LEN:  521 	EPS:  0.889
# ITER:  320 	RWD:  89.65 	M_RWD:  56.13 	LEN:  636 	EPS:  0.8884
# ITER:  321 	RWD:  14.85 	M_RWD:  56.11 	LEN:  71 	EPS:  0.8883
# ITER:  322 	RWD:  53.55 	M_RWD:  56.0 	LEN:  198 	EPS:  0.8881
# ITER:  323 	RWD:  57.55 	M_RWD:  56.4 	LEN:  173 	EPS:  0.8879
# ITER:  324 	RWD:  58.85 	M_RWD:  56.4 	LEN:  178 	EPS:  0.8878
# ITER:  325 	RWD:  58.6 	M_RWD:  56.44 	LEN:  87 	EPS:  0.8877
# ITER:  326 	RWD:  18.65 	M_RWD:  55.19 	LEN:  37 	EPS:  0.8876
# ITER:  327 	RWD:  51.95 	M_RWD:  54.64 	LEN:  1163 	EPS:  0.8865
# ITER:  328 	RWD:  53.45 	M_RWD:  54.99 	LEN:  187 	EPS:  0.8863
# ITER:  329 	RWD:  55.4 	M_RWD:  54.78 	LEN:  184 	EPS:  0.8861
# ITER:  330 	RWD:  63.75 	M_RWD:  54.72 	LEN:  1960 	EPS:  0.8841
# ITER:  331 	RWD:  67.8 	M_RWD:  54.49 	LEN:  446 	EPS:  0.8837
# ITER:  332 	RWD:  102.7 	M_RWD:  54.5 	LEN:  429 	EPS:  0.8833
# ITER:  333 	RWD:  56.5 	M_RWD:  54.5 	LEN:  169 	EPS:  0.8831
# ITER:  334 	RWD:  67.7 	M_RWD:  54.58 	LEN:  512 	EPS:  0.8826
# ITER:  335 	RWD:  92.8 	M_RWD:  54.91 	LEN:  477 	EPS:  0.8821
# ITER:  336 	RWD:  101.9 	M_RWD:  55.74 	LEN:  603 	EPS:  0.8815
# ITER:  337 	RWD:  70.65 	M_RWD:  55.25 	LEN:  405 	EPS:  0.8811
# ITER:  338 	RWD:  63.75 	M_RWD:  55.72 	LEN:  767 	EPS:  0.8803
# ITER:  339 	RWD:  16.15 	M_RWD:  55.3 	LEN:  66 	EPS:  0.8803
# ITER:  340 	RWD:  70.9 	M_RWD:  54.77 	LEN:  343 	EPS:  0.8799
# ITER:  341 	RWD:  53.6 	M_RWD:  54.78 	LEN:  140 	EPS:  0.8798
# ITER:  342 	RWD:  93.85 	M_RWD:  55.0 	LEN:  393 	EPS:  0.8794
# ITER:  343 	RWD:  74.9 	M_RWD:  55.22 	LEN:  161 	EPS:  0.8792
# ITER:  344 	RWD:  53.6 	M_RWD:  55.22 	LEN:  125 	EPS:  0.8791
# ITER:  345 	RWD:  53.9 	M_RWD:  55.18 	LEN:  202 	EPS:  0.8789
# ITER:  346 	RWD:  57.6 	M_RWD:  54.76 	LEN:  149 	EPS:  0.8787
# ITER:  347 	RWD:  116.6 	M_RWD:  55.75 	LEN:  1256 	EPS:  0.8775
# ITER:  348 	RWD:  73.05 	M_RWD:  55.95 	LEN:  1518 	EPS:  0.876
# ITER:  349 	RWD:  55.15 	M_RWD:  55.96 	LEN:  786 	EPS:  0.8752
# ITER:  350 	RWD:  18.05 	M_RWD:  55.55 	LEN:  45 	EPS:  0.8751
# ITER:  351 	RWD:  133.9 	M_RWD:  56.72 	LEN:  378 	EPS:  0.8748
# ITER:  352 	RWD:  78.55 	M_RWD:  56.42 	LEN:  1253 	EPS:  0.8735
# ITER:  353 	RWD:  56.9 	M_RWD:  56.3 	LEN:  203 	EPS:  0.8733
# ITER:  354 	RWD:  82.75 	M_RWD:  56.95 	LEN:  1021 	EPS:  0.8723
# ITER:  355 	RWD:  53.1 	M_RWD:  56.92 	LEN:  282 	EPS:  0.872
# ITER:  356 	RWD:  64.2 	M_RWD:  57.39 	LEN:  774 	EPS:  0.8712
# ITER:  357 	RWD:  122.9 	M_RWD:  57.63 	LEN:  415 	EPS:  0.8708
# ITER:  358 	RWD:  84.75 	M_RWD:  58.35 	LEN:  821 	EPS:  0.87
# ITER:  359 	RWD:  58.25 	M_RWD:  58.26 	LEN:  137 	EPS:  0.8699
# ITER:  360 	RWD:  92.5 	M_RWD:  59.0 	LEN:  541 	EPS:  0.8693
# ITER:  361 	RWD:  18.8 	M_RWD:  58.45 	LEN:  43 	EPS:  0.8693
# ITER:  362 	RWD:  17.7 	M_RWD:  58.45 	LEN:  49 	EPS:  0.8692
# ITER:  363 	RWD:  93.15 	M_RWD:  57.82 	LEN:  506 	EPS:  0.8687
# ITER:  364 	RWD:  90.8 	M_RWD:  58.23 	LEN:  569 	EPS:  0.8682
# ITER:  365 	RWD:  16.15 	M_RWD:  57.81 	LEN:  54 	EPS:  0.8681
# ITER:  366 	RWD:  56.2 	M_RWD:  57.44 	LEN:  100 	EPS:  0.868
# ITER:  367 	RWD:  54.15 	M_RWD:  57.13 	LEN:  165 	EPS:  0.8678
# ITER:  368 	RWD:  55.05 	M_RWD:  56.88 	LEN:  220 	EPS:  0.8676
# ITER:  369 	RWD:  17.7 	M_RWD:  56.88 	LEN:  44 	EPS:  0.8676
# ITER:  370 	RWD:  64.9 	M_RWD:  57.34 	LEN:  539 	EPS:  0.867
# ITER:  371 	RWD:  108.8 	M_RWD:  57.85 	LEN:  1163 	EPS:  0.8659
# ITER:  372 	RWD:  60.95 	M_RWD:  57.9 	LEN:  743 	EPS:  0.8651
# ITER:  373 	RWD:  18.05 	M_RWD:  56.89 	LEN:  37 	EPS:  0.8651
# ITER:  374 	RWD:  71.7 	M_RWD:  56.39 	LEN:  456 	EPS:  0.8646
# ITER:  375 	RWD:  57.0 	M_RWD:  56.78 	LEN:  113 	EPS:  0.8645
# ITER:  376 	RWD:  56.15 	M_RWD:  56.76 	LEN:  212 	EPS:  0.8643
# ITER:  377 	RWD:  80.5 	M_RWD:  57.45 	LEN:  1146 	EPS:  0.8632
# ITER:  378 	RWD:  21.45 	M_RWD:  56.45 	LEN:  2005 	EPS:  0.8612
# ITER:  379 	RWD:  16.6 	M_RWD:  55.65 	LEN:  59 	EPS:  0.8611
# ITER:  380 	RWD:  55.6 	M_RWD:  56.04 	LEN:  105 	EPS:  0.861
# ITER:  381 	RWD:  66.4 	M_RWD:  56.53 	LEN:  160 	EPS:  0.8608
# ITER:  382 	RWD:  58.75 	M_RWD:  56.6 	LEN:  165 	EPS:  0.8607
# ITER:  383 	RWD:  101.15 	M_RWD:  57.09 	LEN:  1479 	EPS:  0.8592
# ITER:  384 	RWD:  56.25 	M_RWD:  56.77 	LEN:  160 	EPS:  0.859
# ITER:  385 	RWD:  16.75 	M_RWD:  56.78 	LEN:  56 	EPS:  0.859
# ITER:  386 	RWD:  74.35 	M_RWD:  56.34 	LEN:  256 	EPS:  0.8587
# ITER:  387 	RWD:  47.05 	M_RWD:  56.19 	LEN:  1185 	EPS:  0.8575
# ITER:  388 	RWD:  64.55 	M_RWD:  56.67 	LEN:  355 	EPS:  0.8572
# ITER:  389 	RWD:  103.25 	M_RWD:  57.52 	LEN:  481 	EPS:  0.8567
# ITER:  390 	RWD:  15.6 	M_RWD:  57.48 	LEN:  47 	EPS:  0.8566
# ITER:  391 	RWD:  91.75 	M_RWD:  57.82 	LEN:  513 	EPS:  0.8561
# ITER:  392 	RWD:  73.2 	M_RWD:  58.15 	LEN:  335 	EPS:  0.8558
# ITER:  393 	RWD:  68.8 	M_RWD:  57.9 	LEN:  352 	EPS:  0.8554
# ITER:  394 	RWD:  57.95 	M_RWD:  58.32 	LEN:  229 	EPS:  0.8552
# ITER:  395 	RWD:  66.05 	M_RWD:  58.83 	LEN:  357 	EPS:  0.8549
# ITER:  396 	RWD:  73.2 	M_RWD:  58.94 	LEN:  306 	EPS:  0.8546
# ITER:  397 	RWD:  58.65 	M_RWD:  58.97 	LEN:  162 	EPS:  0.8544
# ITER:  398 	RWD:  110.95 	M_RWD:  59.55 	LEN:  1028 	EPS:  0.8534
# ITER:  399 	RWD:  113.9 	M_RWD:  60.5 	LEN:  784 	EPS:  0.8526
# ITER:  400 	RWD:  83.35 	M_RWD:  60.79 	LEN:  942 	EPS:  0.8516
# ITER:  401 	RWD:  13.3 	M_RWD:  60.73 	LEN:  68 	EPS:  0.8516
# ITER:  402 	RWD:  16.5 	M_RWD:  60.33 	LEN:  50 	EPS:  0.8515
# ITER:  403 	RWD:  54.1 	M_RWD:  59.91 	LEN:  172 	EPS:  0.8513
# ITER:  404 	RWD:  67.5 	M_RWD:  60.03 	LEN:  2005 	EPS:  0.8493
# ITER:  405 	RWD:  127.55 	M_RWD:  60.59 	LEN:  230 	EPS:  0.8491
# ITER:  406 	RWD:  57.05 	M_RWD:  60.98 	LEN:  197 	EPS:  0.8489
# ITER:  407 	RWD:  55.95 	M_RWD:  61.02 	LEN:  198 	EPS:  0.8487
# ITER:  408 	RWD:  55.7 	M_RWD:  61.38 	LEN:  96 	EPS:  0.8486
# ITER:  409 	RWD:  55.8 	M_RWD:  60.88 	LEN:  118 	EPS:  0.8485
# ITER:  410 	RWD:  16.45 	M_RWD:  60.48 	LEN:  52 	EPS:  0.8485
# ITER:  411 	RWD:  14.5 	M_RWD:  60.43 	LEN:  60 	EPS:  0.8484
# ITER:  412 	RWD:  97.55 	M_RWD:  61.22 	LEN:  374 	EPS:  0.848
# ITER:  413 	RWD:  17.25 	M_RWD:  60.87 	LEN:  51 	EPS:  0.848
# ITER:  414 	RWD:  58.1 	M_RWD:  60.83 	LEN:  233 	EPS:  0.8477
# ITER:  415 	RWD:  122.0 	M_RWD:  61.5 	LEN:  461 	EPS:  0.8473
# ITER:  416 	RWD:  53.3 	M_RWD:  61.87 	LEN:  764 	EPS:  0.8465
# ITER:  417 	RWD:  16.7 	M_RWD:  61.86 	LEN:  44 	EPS:  0.8465
# ITER:  418 	RWD:  54.4 	M_RWD:  62.21 	LEN:  138 	EPS:  0.8463
# ITER:  419 	RWD:  70.8 	M_RWD:  62.23 	LEN:  453 	EPS:  0.8459
# ITER:  420 	RWD:  66.2 	M_RWD:  62.0 	LEN:  537 	EPS:  0.8453
# ITER:  421 	RWD:  90.55 	M_RWD:  62.75 	LEN:  680 	EPS:  0.8447
# [INFO] Saving model
# [INFO] Saving model
# ITER:  422 	RWD:  70.3 	M_RWD:  62.92 	LEN:  220 	EPS:  0.8444
# [INFO] Saving model
# [INFO] Saving model
# ITER:  423 	RWD:  60.3 	M_RWD:  62.95 	LEN:  572 	EPS:  0.8439
# [INFO] Saving model
# [INFO] Saving model
# ITER:  424 	RWD:  70.3 	M_RWD:  63.06 	LEN:  452 	EPS:  0.8434
# [INFO] Saving model
# [INFO] Saving model
# ITER:  425 	RWD:  65.95 	M_RWD:  63.14 	LEN:  684 	EPS:  0.8427
# [INFO] Saving model
# [INFO] Saving model
# ITER:  426 	RWD:  54.9 	M_RWD:  63.5 	LEN:  117 	EPS:  0.8426
# [INFO] Saving model
# [INFO] Saving model
# ITER:  427 	RWD:  109.85 	M_RWD:  64.08 	LEN:  1575 	EPS:  0.841
# ITER:  428 	RWD:  16.05 	M_RWD:  63.7 	LEN:  63 	EPS:  0.841
# ITER:  429 	RWD:  19.3 	M_RWD:  63.34 	LEN:  40 	EPS:  0.8409
# ITER:  430 	RWD:  63.6 	M_RWD:  63.34 	LEN:  476 	EPS:  0.8405
# ITER:  431 	RWD:  13.4 	M_RWD:  62.8 	LEN:  57 	EPS:  0.8404
# ITER:  432 	RWD:  62.05 	M_RWD:  62.39 	LEN:  651 	EPS:  0.8398
# ITER:  433 	RWD:  17.45 	M_RWD:  62.0 	LEN:  43 	EPS:  0.8397
# ITER:  434 	RWD:  66.55 	M_RWD:  61.99 	LEN:  647 	EPS:  0.8391
# ITER:  435 	RWD:  55.55 	M_RWD:  61.62 	LEN:  129 	EPS:  0.8389
# ITER:  436 	RWD:  19.7 	M_RWD:  60.79 	LEN:  39 	EPS:  0.8389
# ITER:  437 	RWD:  56.55 	M_RWD:  60.65 	LEN:  109 	EPS:  0.8388
# ITER:  438 	RWD:  56.95 	M_RWD:  60.58 	LEN:  247 	EPS:  0.8385
# ITER:  439 	RWD:  19.5 	M_RWD:  60.62 	LEN:  38 	EPS:  0.8385
# ITER:  440 	RWD:  17.2 	M_RWD:  60.08 	LEN:  42 	EPS:  0.8385
# ITER:  441 	RWD:  71.8 	M_RWD:  60.26 	LEN:  257 	EPS:  0.8382
# ITER:  442 	RWD:  97.85 	M_RWD:  60.3 	LEN:  257 	EPS:  0.8379
# ITER:  443 	RWD:  122.4 	M_RWD:  60.78 	LEN:  479 	EPS:  0.8375
# ITER:  444 	RWD:  70.6 	M_RWD:  60.95 	LEN:  463 	EPS:  0.837
# ITER:  445 	RWD:  55.5 	M_RWD:  60.96 	LEN:  100 	EPS:  0.8369
# ITER:  446 	RWD:  54.65 	M_RWD:  60.93 	LEN:  105 	EPS:  0.8368
# ITER:  447 	RWD:  19.0 	M_RWD:  59.96 	LEN:  38 	EPS:  0.8368
# ITER:  448 	RWD:  16.6 	M_RWD:  59.39 	LEN:  48 	EPS:  0.8367
# ITER:  449 	RWD:  16.2 	M_RWD:  59.0 	LEN:  46 	EPS:  0.8367
# ITER:  450 	RWD:  15.5 	M_RWD:  58.98 	LEN:  58 	EPS:  0.8366
# ITER:  451 	RWD:  19.0 	M_RWD:  57.83 	LEN:  47 	EPS:  0.8366
# ITER:  452 	RWD:  13.3 	M_RWD:  57.18 	LEN:  63 	EPS:  0.8365
# ITER:  453 	RWD:  18.6 	M_RWD:  56.79 	LEN:  37 	EPS:  0.8365
# ITER:  454 	RWD:  17.4 	M_RWD:  56.14 	LEN:  45 	EPS:  0.8364
# ITER:  455 	RWD:  57.25 	M_RWD:  56.18 	LEN:  106 	EPS:  0.8363
# ITER:  456 	RWD:  17.65 	M_RWD:  55.72 	LEN:  39 	EPS:  0.8363
# ITER:  457 	RWD:  73.15 	M_RWD:  55.22 	LEN:  371 	EPS:  0.8359
# ITER:  458 	RWD:  18.65 	M_RWD:  54.56 	LEN:  36 	EPS:  0.8359
# ITER:  459 	RWD:  55.75 	M_RWD:  54.53 	LEN:  96 	EPS:  0.8358
# ITER:  460 	RWD:  57.15 	M_RWD:  54.18 	LEN:  92 	EPS:  0.8357
# ITER:  461 	RWD:  58.55 	M_RWD:  54.58 	LEN:  174 	EPS:  0.8355
# ITER:  462 	RWD:  56.55 	M_RWD:  54.97 	LEN:  70 	EPS:  0.8354
# ITER:  463 	RWD:  17.8 	M_RWD:  54.21 	LEN:  45 	EPS:  0.8354
# ITER:  464 	RWD:  122.5 	M_RWD:  54.53 	LEN:  523 	EPS:  0.8349
# ITER:  465 	RWD:  56.9 	M_RWD:  54.94 	LEN:  111 	EPS:  0.8348
# ITER:  466 	RWD:  94.8 	M_RWD:  55.32 	LEN:  435 	EPS:  0.8343
# ITER:  467 	RWD:  19.2 	M_RWD:  54.97 	LEN:  41 	EPS:  0.8343
# ITER:  468 	RWD:  12.8 	M_RWD:  54.55 	LEN:  60 	EPS:  0.8342
# ITER:  469 	RWD:  19.1 	M_RWD:  54.57 	LEN:  42 	EPS:  0.8342
# ITER:  470 	RWD:  58.5 	M_RWD:  54.5 	LEN:  163 	EPS:  0.834
# ITER:  471 	RWD:  64.9 	M_RWD:  54.06 	LEN:  314 	EPS:  0.8337
# ITER:  472 	RWD:  17.9 	M_RWD:  53.63 	LEN:  62 	EPS:  0.8336
# ITER:  473 	RWD:  63.35 	M_RWD:  54.08 	LEN:  322 	EPS:  0.8333
# ITER:  474 	RWD:  55.55 	M_RWD:  53.92 	LEN:  132 	EPS:  0.8332
# ITER:  475 	RWD:  20.3 	M_RWD:  53.56 	LEN:  34 	EPS:  0.8331
# ITER:  476 	RWD:  60.1 	M_RWD:  53.6 	LEN:  82 	EPS:  0.8331
# ITER:  477 	RWD:  17.6 	M_RWD:  52.97 	LEN:  44 	EPS:  0.833
# ITER:  478 	RWD:  71.4 	M_RWD:  53.47 	LEN:  1604 	EPS:  0.8314
# ITER:  479 	RWD:  12.6 	M_RWD:  53.43 	LEN:  59 	EPS:  0.8314
# ITER:  480 	RWD:  69.95 	M_RWD:  53.57 	LEN:  533 	EPS:  0.8308
# ITER:  481 	RWD:  109.6 	M_RWD:  54.0 	LEN:  1062 	EPS:  0.8298
# ITER:  482 	RWD:  17.95 	M_RWD:  53.59 	LEN:  46 	EPS:  0.8297
# ITER:  483 	RWD:  16.3 	M_RWD:  52.75 	LEN:  46 	EPS:  0.8297
# ITER:  484 	RWD:  15.4 	M_RWD:  52.34 	LEN:  55 	EPS:  0.8296
# ITER:  485 	RWD:  76.25 	M_RWD:  52.93 	LEN:  190 	EPS:  0.8294
# ITER:  486 	RWD:  17.55 	M_RWD:  52.36 	LEN:  61 	EPS:  0.8294
# ITER:  487 	RWD:  16.2 	M_RWD:  52.06 	LEN:  60 	EPS:  0.8293
# ITER:  488 	RWD:  62.5 	M_RWD:  52.03 	LEN:  893 	EPS:  0.8284
# ITER:  489 	RWD:  16.2 	M_RWD:  51.16 	LEN:  58 	EPS:  0.8284
# ITER:  490 	RWD:  54.2 	M_RWD:  51.55 	LEN:  103 	EPS:  0.8283
# ITER:  491 	RWD:  18.8 	M_RWD:  50.82 	LEN:  38 	EPS:  0.8282
# ITER:  492 	RWD:  66.15 	M_RWD:  50.75 	LEN:  289 	EPS:  0.8279
# ITER:  493 	RWD:  18.45 	M_RWD:  50.25 	LEN:  40 	EPS:  0.8279
# ITER:  494 	RWD:  58.4 	M_RWD:  50.25 	LEN:  583 	EPS:  0.8273
# ITER:  495 	RWD:  49.75 	M_RWD:  50.09 	LEN:  251 	EPS:  0.827
# ITER:  496 	RWD:  54.95 	M_RWD:  49.91 	LEN:  378 	EPS:  0.8267
# ITER:  497 	RWD:  58.05 	M_RWD:  49.9 	LEN:  169 	EPS:  0.8265
# ITER:  498 	RWD:  101.15 	M_RWD:  49.8 	LEN:  1475 	EPS:  0.825
# ITER:  499 	RWD:  120.85 	M_RWD:  49.87 	LEN:  582 	EPS:  0.8244
# ITER:  500 	RWD:  49.9 	M_RWD:  49.54 	LEN:  121 	EPS:  0.8243
# ITER:  501 	RWD:  57.25 	M_RWD:  49.98 	LEN:  238 	EPS:  0.8241
# ITER:  502 	RWD:  52.65 	M_RWD:  50.34 	LEN:  151 	EPS:  0.8239
# ITER:  503 	RWD:  69.85 	M_RWD:  50.5 	LEN:  321 	EPS:  0.8236
# ITER:  504 	RWD:  96.85 	M_RWD:  50.79 	LEN:  1702 	EPS:  0.8219
# ITER:  505 	RWD:  57.55 	M_RWD:  50.09 	LEN:  222 	EPS:  0.8217
# ITER:  506 	RWD:  116.6 	M_RWD:  50.68 	LEN:  729 	EPS:  0.821
# ITER:  507 	RWD:  79.35 	M_RWD:  50.92 	LEN:  1094 	EPS:  0.8199
# ITER:  508 	RWD:  16.05 	M_RWD:  50.52 	LEN:  47 	EPS:  0.8198
# ITER:  509 	RWD:  53.95 	M_RWD:  50.5 	LEN:  138 	EPS:  0.8197
# ITER:  510 	RWD:  93.45 	M_RWD:  51.27 	LEN:  489 	EPS:  0.8192
# ITER:  511 	RWD:  117.55 	M_RWD:  52.3 	LEN:  614 	EPS:  0.8186
# ITER:  512 	RWD:  132.35 	M_RWD:  52.65 	LEN:  1133 	EPS:  0.8174
# ITER:  513 	RWD:  16.3 	M_RWD:  52.64 	LEN:  43 	EPS:  0.8174
# ITER:  514 	RWD:  96.9 	M_RWD:  53.03 	LEN:  270 	EPS:  0.8171
# ITER:  515 	RWD:  113.95 	M_RWD:  52.95 	LEN:  973 	EPS:  0.8162
# ITER:  516 	RWD:  15.95 	M_RWD:  52.58 	LEN:  43 	EPS:  0.8161
# ITER:  517 	RWD:  15.9 	M_RWD:  52.57 	LEN:  57 	EPS:  0.8161
# ITER:  518 	RWD:  85.75 	M_RWD:  52.88 	LEN:  895 	EPS:  0.8152
# ITER:  519 	RWD:  53.55 	M_RWD:  52.71 	LEN:  111 	EPS:  0.8151
# ITER:  520 	RWD:  58.55 	M_RWD:  52.63 	LEN:  168 	EPS:  0.8149
# ITER:  521 	RWD:  40.3 	M_RWD:  52.13 	LEN:  2005 	EPS:  0.8129
# ITER:  522 	RWD:  60.3 	M_RWD:  52.03 	LEN:  2005 	EPS:  0.8109
# ITER:  523 	RWD:  17.45 	M_RWD:  51.6 	LEN:  39 	EPS:  0.8108
# ITER:  524 	RWD:  124.35 	M_RWD:  52.14 	LEN:  473 	EPS:  0.8104
# ITER:  525 	RWD:  95.25 	M_RWD:  52.44 	LEN:  355 	EPS:  0.81
# ITER:  526 	RWD:  72.35 	M_RWD:  52.61 	LEN:  314 	EPS:  0.8097
# ITER:  527 	RWD:  55.35 	M_RWD:  52.06 	LEN:  73 	EPS:  0.8096
# ITER:  528 	RWD:  99.95 	M_RWD:  52.9 	LEN:  159 	EPS:  0.8095
# ITER:  529 	RWD:  57.8 	M_RWD:  53.29 	LEN:  765 	EPS:  0.8087
# ITER:  530 	RWD:  17.05 	M_RWD:  52.82 	LEN:  54 	EPS:  0.8086
# ITER:  531 	RWD:  58.95 	M_RWD:  53.28 	LEN:  154 	EPS:  0.8085
# ITER:  532 	RWD:  17.15 	M_RWD:  52.83 	LEN:  44 	EPS:  0.8084
# ITER:  533 	RWD:  18.2 	M_RWD:  52.84 	LEN:  53 	EPS:  0.8084
# ITER:  534 	RWD:  163.6 	M_RWD:  53.81 	LEN:  294 	EPS:  0.8081
# ITER:  535 	RWD:  49.6 	M_RWD:  53.75 	LEN:  242 	EPS:  0.8079
# ITER:  536 	RWD:  89.6 	M_RWD:  54.45 	LEN:  637 	EPS:  0.8072
# ITER:  537 	RWD:  97.65 	M_RWD:  54.86 	LEN:  281 	EPS:  0.8069
# ITER:  538 	RWD:  114.4 	M_RWD:  55.43 	LEN:  902 	EPS:  0.806
# ITER:  539 	RWD:  52.65 	M_RWD:  55.76 	LEN:  367 	EPS:  0.8057
# ITER:  540 	RWD:  70.4 	M_RWD:  56.3 	LEN:  224 	EPS:  0.8054
# ITER:  541 	RWD:  63.45 	M_RWD:  56.21 	LEN:  225 	EPS:  0.8052
# ITER:  542 	RWD:  68.9 	M_RWD:  55.92 	LEN:  143 	EPS:  0.8051
# ITER:  543 	RWD:  19.65 	M_RWD:  54.9 	LEN:  32 	EPS:  0.805
# ITER:  544 	RWD:  19.5 	M_RWD:  54.38 	LEN:  40 	EPS:  0.805
# ITER:  545 	RWD:  17.7 	M_RWD:  54.01 	LEN:  46 	EPS:  0.805
# ITER:  546 	RWD:  58.0 	M_RWD:  54.04 	LEN:  1067 	EPS:  0.8039
# ITER:  547 	RWD:  71.05 	M_RWD:  54.56 	LEN:  199 	EPS:  0.8037
# ITER:  548 	RWD:  19.25 	M_RWD:  54.59 	LEN:  37 	EPS:  0.8037
# ITER:  549 	RWD:  56.9 	M_RWD:  54.99 	LEN:  244 	EPS:  0.8034
# ITER:  550 	RWD:  20.0 	M_RWD:  55.04 	LEN:  28 	EPS:  0.8034
# ITER:  551 	RWD:  58.0 	M_RWD:  55.43 	LEN:  85 	EPS:  0.8033
# ITER:  552 	RWD:  59.5 	M_RWD:  55.89 	LEN:  111 	EPS:  0.8032
# ITER:  553 	RWD:  16.7 	M_RWD:  55.87 	LEN:  40 	EPS:  0.8031
# ITER:  554 	RWD:  19.2 	M_RWD:  55.89 	LEN:  37 	EPS:  0.8031
# ITER:  555 	RWD:  60.05 	M_RWD:  55.92 	LEN:  765 	EPS:  0.8023
# ITER:  556 	RWD:  10.05 	M_RWD:  55.84 	LEN:  73 	EPS:  0.8023
# ITER:  557 	RWD:  53.3 	M_RWD:  55.64 	LEN:  143 	EPS:  0.8021
# ITER:  558 	RWD:  95.65 	M_RWD:  56.41 	LEN:  374 	EPS:  0.8018
# ITER:  559 	RWD:  57.45 	M_RWD:  56.43 	LEN:  152 	EPS:  0.8016
# ITER:  560 	RWD:  18.7 	M_RWD:  56.05 	LEN:  40 	EPS:  0.8016
# ITER:  561 	RWD:  64.8 	M_RWD:  56.11 	LEN:  427 	EPS:  0.8011
# ITER:  562 	RWD:  109.43 	M_RWD:  56.64 	LEN:  1210 	EPS:  0.7999
# ITER:  563 	RWD:  86.13 	M_RWD:  57.32 	LEN:  684 	EPS:  0.7992
# ITER:  564 	RWD:  40.05 	M_RWD:  56.5 	LEN:  2005 	EPS:  0.7972
# ITER:  565 	RWD:  14.9 	M_RWD:  56.08 	LEN:  51 	EPS:  0.7972
# ITER:  566 	RWD:  58.55 	M_RWD:  55.71 	LEN:  120 	EPS:  0.7971
# ITER:  567 	RWD:  64.65 	M_RWD:  56.17 	LEN:  724 	EPS:  0.7963
# ITER:  568 	RWD:  48.15 	M_RWD:  56.52 	LEN:  1377 	EPS:  0.795
# ITER:  569 	RWD:  58.85 	M_RWD:  56.92 	LEN:  153 	EPS:  0.7948
# ITER:  570 	RWD:  18.9 	M_RWD:  56.52 	LEN:  44 	EPS:  0.7948
# ITER:  571 	RWD:  55.45 	M_RWD:  56.43 	LEN:  181 	EPS:  0.7946
# ITER:  572 	RWD:  57.4 	M_RWD:  56.82 	LEN:  179 	EPS:  0.7944
# ITER:  573 	RWD:  57.1 	M_RWD:  56.76 	LEN:  177 	EPS:  0.7942
# ITER:  574 	RWD:  61.8 	M_RWD:  56.82 	LEN:  875 	EPS:  0.7934
# ITER:  575 	RWD:  17.55 	M_RWD:  56.8 	LEN:  50 	EPS:  0.7933
# ITER:  576 	RWD:  15.9 	M_RWD:  56.35 	LEN:  51 	EPS:  0.7933
# ITER:  577 	RWD:  18.8 	M_RWD:  56.37 	LEN:  40 	EPS:  0.7932
# ITER:  578 	RWD:  55.1 	M_RWD:  56.2 	LEN:  306 	EPS:  0.7929
# ITER:  579 	RWD:  92.15 	M_RWD:  57.0 	LEN:  609 	EPS:  0.7923
# ITER:  580 	RWD:  80.9 	M_RWD:  57.11 	LEN:  1115 	EPS:  0.7912
# ITER:  581 	RWD:  16.95 	M_RWD:  56.18 	LEN:  64 	EPS:  0.7911
# ITER:  582 	RWD:  19.2 	M_RWD:  56.19 	LEN:  39 	EPS:  0.7911
# ITER:  583 	RWD:  58.35 	M_RWD:  56.61 	LEN:  155 	EPS:  0.7909
# ITER:  584 	RWD:  14.65 	M_RWD:  56.61 	LEN:  53 	EPS:  0.7909
# ITER:  585 	RWD:  58.9 	M_RWD:  56.43 	LEN:  164 	EPS:  0.7907
# ITER:  586 	RWD:  55.4 	M_RWD:  56.81 	LEN:  128 	EPS:  0.7906
# ITER:  587 	RWD:  58.4 	M_RWD:  57.23 	LEN:  167 	EPS:  0.7904
# ITER:  588 	RWD:  18.2 	M_RWD:  56.79 	LEN:  51 	EPS:  0.7904
# ITER:  589 	RWD:  121.5 	M_RWD:  57.84 	LEN:  647 	EPS:  0.7897
# ITER:  590 	RWD:  57.5 	M_RWD:  57.88 	LEN:  174 	EPS:  0.7895
# ITER:  591 	RWD:  89.95 	M_RWD:  58.59 	LEN:  606 	EPS:  0.7889
# ITER:  592 	RWD:  16.75 	M_RWD:  58.09 	LEN:  41 	EPS:  0.7889
# ITER:  593 	RWD:  81.03 	M_RWD:  58.72 	LEN:  1283 	EPS:  0.7876
# ITER:  594 	RWD:  36.37 	M_RWD:  58.5 	LEN:  2005 	EPS:  0.7856
# ITER:  595 	RWD:  56.2 	M_RWD:  58.56 	LEN:  149 	EPS:  0.7855
# ITER:  596 	RWD:  95.2 	M_RWD:  58.97 	LEN:  381 	EPS:  0.7851
# ITER:  597 	RWD:  53.2 	M_RWD:  58.92 	LEN:  180 	EPS:  0.7849
# ITER:  598 	RWD:  19.5 	M_RWD:  58.1 	LEN:  37 	EPS:  0.7849
# ITER:  599 	RWD:  55.55 	M_RWD:  57.45 	LEN:  201 	EPS:  0.7847
# ITER:  600 	RWD:  54.65 	M_RWD:  57.5 	LEN:  188 	EPS:  0.7845
# ITER:  601 	RWD:  18.6 	M_RWD:  57.11 	LEN:  37 	EPS:  0.7844
# ITER:  602 	RWD:  70.15 	M_RWD:  57.29 	LEN:  326 	EPS:  0.7841
# ITER:  603 	RWD:  53.45 	M_RWD:  57.12 	LEN:  150 	EPS:  0.784
# ITER:  604 	RWD:  72.65 	M_RWD:  56.88 	LEN:  266 	EPS:  0.7837
# ITER:  605 	RWD:  56.55 	M_RWD:  56.87 	LEN:  223 	EPS:  0.7835
# ITER:  606 	RWD:  62.1 	M_RWD:  56.32 	LEN:  579 	EPS:  0.7829
# ITER:  607 	RWD:  94.95 	M_RWD:  56.48 	LEN:  381 	EPS:  0.7825
# ITER:  608 	RWD:  18.55 	M_RWD:  56.51 	LEN:  38 	EPS:  0.7825
# ITER:  609 	RWD:  16.9 	M_RWD:  56.13 	LEN:  47 	EPS:  0.7824
# ITER:  610 	RWD:  66.6 	M_RWD:  55.87 	LEN:  487 	EPS:  0.7819
# ITER:  611 	RWD:  85.45 	M_RWD:  55.55 	LEN:  946 	EPS:  0.781
# ITER:  612 	RWD:  84.05 	M_RWD:  55.06 	LEN:  940 	EPS:  0.7801
# ITER:  613 	RWD:  67.65 	M_RWD:  55.58 	LEN:  406 	EPS:  0.7796
# ITER:  614 	RWD:  91.5 	M_RWD:  55.52 	LEN:  711 	EPS:  0.7789
# ITER:  615 	RWD:  85.1 	M_RWD:  55.23 	LEN:  758 	EPS:  0.7782
# ITER:  616 	RWD:  16.15 	M_RWD:  55.24 	LEN:  49 	EPS:  0.7781
# ITER:  617 	RWD:  98.6 	M_RWD:  56.06 	LEN:  299 	EPS:  0.7778
# ITER:  618 	RWD:  18.2 	M_RWD:  55.39 	LEN:  69 	EPS:  0.7778
# ITER:  619 	RWD:  18.7 	M_RWD:  55.04 	LEN:  38 	EPS:  0.7777
# ITER:  620 	RWD:  53.35 	M_RWD:  54.99 	LEN:  253 	EPS:  0.7775
# ITER:  621 	RWD:  68.6 	M_RWD:  55.27 	LEN:  562 	EPS:  0.7769
# ITER:  622 	RWD:  61.7 	M_RWD:  55.28 	LEN:  567 	EPS:  0.7763
# ITER:  623 	RWD:  56.35 	M_RWD:  55.67 	LEN:  123 	EPS:  0.7762
# ITER:  624 	RWD:  56.75 	M_RWD:  55.0 	LEN:  165 	EPS:  0.7761
# ITER:  625 	RWD:  55.5 	M_RWD:  54.6 	LEN:  136 	EPS:  0.7759
# ITER:  626 	RWD:  57.6 	M_RWD:  54.45 	LEN:  110 	EPS:  0.7758
# ITER:  627 	RWD:  61.05 	M_RWD:  54.51 	LEN:  540 	EPS:  0.7753
# ITER:  628 	RWD:  120.65 	M_RWD:  54.72 	LEN:  429 	EPS:  0.7748
# ITER:  629 	RWD:  16.05 	M_RWD:  54.3 	LEN:  46 	EPS:  0.7748
# ITER:  630 	RWD:  53.7 	M_RWD:  54.66 	LEN:  141 	EPS:  0.7747
# ITER:  631 	RWD:  91.0 	M_RWD:  54.98 	LEN:  625 	EPS:  0.774
# ITER:  632 	RWD:  15.4 	M_RWD:  54.97 	LEN:  59 	EPS:  0.774
# ITER:  633 	RWD:  54.25 	M_RWD:  55.33 	LEN:  188 	EPS:  0.7738
# ITER:  634 	RWD:  67.5 	M_RWD:  54.37 	LEN:  381 	EPS:  0.7734
# ITER:  635 	RWD:  18.35 	M_RWD:  54.05 	LEN:  40 	EPS:  0.7734
# ITER:  636 	RWD:  88.45 	M_RWD:  54.04 	LEN:  666 	EPS:  0.7727
# ITER:  637 	RWD:  69.15 	M_RWD:  53.76 	LEN:  484 	EPS:  0.7722
# ITER:  638 	RWD:  67.2 	M_RWD:  53.29 	LEN:  181 	EPS:  0.772
# ITER:  639 	RWD:  59.05 	M_RWD:  53.35 	LEN:  102 	EPS:  0.7719
# ITER:  640 	RWD:  57.0 	M_RWD:  53.22 	LEN:  222 	EPS:  0.7717
# ITER:  641 	RWD:  57.65 	M_RWD:  53.16 	LEN:  181 	EPS:  0.7715
# ITER:  642 	RWD:  119.05 	M_RWD:  53.66 	LEN:  629 	EPS:  0.7709
# ITER:  643 	RWD:  17.35 	M_RWD:  53.64 	LEN:  57 	EPS:  0.7708
# ITER:  644 	RWD:  17.2 	M_RWD:  53.61 	LEN:  46 	EPS:  0.7708
# ITER:  645 	RWD:  58.25 	M_RWD:  54.02 	LEN:  163 	EPS:  0.7706
# ITER:  646 	RWD:  110.95 	M_RWD:  54.55 	LEN:  992 	EPS:  0.7696
# ITER:  647 	RWD:  83.2 	M_RWD:  54.67 	LEN:  1432 	EPS:  0.7682
# ITER:  648 	RWD:  59.75 	M_RWD:  55.07 	LEN:  429 	EPS:  0.7678
# ITER:  649 	RWD:  57.55 	M_RWD:  55.08 	LEN:  224 	EPS:  0.7676
# ITER:  650 	RWD:  112.5 	M_RWD:  56.01 	LEN:  923 	EPS:  0.7666
# ITER:  651 	RWD:  67.6 	M_RWD:  56.1 	LEN:  541 	EPS:  0.7661
# ITER:  652 	RWD:  19.5 	M_RWD:  55.7 	LEN:  33 	EPS:  0.7661
# ITER:  653 	RWD:  18.1 	M_RWD:  55.72 	LEN:  42 	EPS:  0.766
# ITER:  654 	RWD:  46.75 	M_RWD:  55.99 	LEN:  1179 	EPS:  0.7648
# ITER:  655 	RWD:  54.65 	M_RWD:  55.94 	LEN:  129 	EPS:  0.7647
# ITER:  656 	RWD:  98.05 	M_RWD:  56.82 	LEN:  240 	EPS:  0.7645
# ITER:  657 	RWD:  18.15 	M_RWD:  56.47 	LEN:  40 	EPS:  0.7644
# ITER:  658 	RWD:  17.6 	M_RWD:  55.69 	LEN:  39 	EPS:  0.7644
# ITER:  659 	RWD:  71.55 	M_RWD:  55.83 	LEN:  426 	EPS:  0.764
# ITER:  660 	RWD:  55.05 	M_RWD:  56.19 	LEN:  75 	EPS:  0.7639
# ITER:  661 	RWD:  73.35 	M_RWD:  56.28 	LEN:  1523 	EPS:  0.7624
# ITER:  662 	RWD:  17.95 	M_RWD:  55.36 	LEN:  38 	EPS:  0.7623
# ITER:  663 	RWD:  70.2 	M_RWD:  55.2 	LEN:  458 	EPS:  0.7619
# ITER:  664 	RWD:  13.1 	M_RWD:  54.93 	LEN:  57 	EPS:  0.7618
# ITER:  665 	RWD:  204.55 	M_RWD:  56.83 	LEN:  1805 	EPS:  0.76
# ITER:  666 	RWD:  92.0 	M_RWD:  57.16 	LEN:  413 	EPS:  0.7596
# ITER:  667 	RWD:  109.3 	M_RWD:  57.61 	LEN:  1027 	EPS:  0.7586
# ITER:  668 	RWD:  58.15 	M_RWD:  57.71 	LEN:  164 	EPS:  0.7584
# ITER:  669 	RWD:  62.9 	M_RWD:  57.75 	LEN:  850 	EPS:  0.7575
# ITER:  670 	RWD:  80.95 	M_RWD:  58.37 	LEN:  1083 	EPS:  0.7565
# ITER:  671 	RWD:  16.55 	M_RWD:  57.98 	LEN:  42 	EPS:  0.7564
# ITER:  672 	RWD:  53.6 	M_RWD:  57.94 	LEN:  115 	EPS:  0.7563
# ITER:  673 	RWD:  55.85 	M_RWD:  57.93 	LEN:  310 	EPS:  0.756
# ITER:  674 	RWD:  56.5 	M_RWD:  57.88 	LEN:  726 	EPS:  0.7553
# ITER:  675 	RWD:  58.1 	M_RWD:  58.28 	LEN:  184 	EPS:  0.7551
# ITER:  676 	RWD:  111.1 	M_RWD:  59.24 	LEN:  1089 	EPS:  0.754
# ITER:  677 	RWD:  64.9 	M_RWD:  59.7 	LEN:  321 	EPS:  0.7537
# ITER:  678 	RWD:  13.95 	M_RWD:  59.29 	LEN:  60 	EPS:  0.7536
# ITER:  679 	RWD:  95.55 	M_RWD:  59.32 	LEN:  799 	EPS:  0.7528
# ITER:  680 	RWD:  57.35 	M_RWD:  59.08 	LEN:  155 	EPS:  0.7527
# ITER:  681 	RWD:  88.0 	M_RWD:  59.79 	LEN:  835 	EPS:  0.7518
# ITER:  682 	RWD:  68.45 	M_RWD:  60.29 	LEN:  581 	EPS:  0.7512
# ITER:  683 	RWD:  66.8 	M_RWD:  60.37 	LEN:  232 	EPS:  0.751
# ITER:  684 	RWD:  121.35 	M_RWD:  61.44 	LEN:  495 	EPS:  0.7505
# ITER:  685 	RWD:  17.3 	M_RWD:  61.02 	LEN:  43 	EPS:  0.7505
# ITER:  686 	RWD:  17.7 	M_RWD:  60.65 	LEN:  40 	EPS:  0.7504
# ITER:  687 	RWD:  112.45 	M_RWD:  61.19 	LEN:  1039 	EPS:  0.7494
# ITER:  688 	RWD:  53.6 	M_RWD:  61.54 	LEN:  139 	EPS:  0.7493
# ITER:  689 	RWD:  111.15 	M_RWD:  61.44 	LEN:  1112 	EPS:  0.7481
# ITER:  690 	RWD:  106.35 	M_RWD:  61.92 	LEN:  1152 	EPS:  0.747
# ITER:  691 	RWD:  91.55 	M_RWD:  61.94 	LEN:  472 	EPS:  0.7465
# ITER:  692 	RWD:  121.7 	M_RWD:  62.99 	LEN:  483 	EPS:  0.746
# ITER:  693 	RWD:  52.8 	M_RWD:  62.71 	LEN:  153 	EPS:  0.7459
# ITER:  694 	RWD:  57.8 	M_RWD:  62.92 	LEN:  164 	EPS:  0.7457
# ITER:  695 	RWD:  58.4 	M_RWD:  62.94 	LEN:  76 	EPS:  0.7456
# ITER:  696 	RWD:  72.7 	M_RWD:  62.72 	LEN:  326 	EPS:  0.7453
# ITER:  697 	RWD:  70.45 	M_RWD:  62.89 	LEN:  391 	EPS:  0.7449
# ITER:  698 	RWD:  56.25 	M_RWD:  63.26 	LEN:  90 	EPS:  0.7448
# ITER:  699 	RWD:  54.25 	M_RWD:  63.25 	LEN:  159 	EPS:  0.7447
# ITER:  700 	RWD:  69.9 	M_RWD:  63.4 	LEN:  403 	EPS:  0.7443
# [INFO] Saving model
# [INFO] Saving model
# ITER:  701 	RWD:  96.65 	M_RWD:  64.18 	LEN:  330 	EPS:  0.744
# ITER:  702 	RWD:  16.8 	M_RWD:  63.65 	LEN:  42 	EPS:  0.7439
# [INFO] Saving model
# [INFO] Saving model
# ITER:  703 	RWD:  108.85 	M_RWD:  64.2 	LEN:  1140 	EPS:  0.7428
# ITER:  704 	RWD:  54.9 	M_RWD:  64.02 	LEN:  104 	EPS:  0.7427
# [INFO] Saving model
# [INFO] Saving model
# ITER:  705 	RWD:  76.0 	M_RWD:  64.22 	LEN:  192 	EPS:  0.7425
# [INFO] Saving model
# [INFO] Saving model
# ITER:  706 	RWD:  78.25 	M_RWD:  64.38 	LEN:  1165 	EPS:  0.7413
# ITER:  707 	RWD:  70.65 	M_RWD:  64.14 	LEN:  417 	EPS:  0.7409
# ITER:  708 	RWD:  18.05 	M_RWD:  64.13 	LEN:  42 	EPS:  0.7408
# ITER:  709 	RWD:  18.9 	M_RWD:  64.15 	LEN:  47 	EPS:  0.7408
# ITER:  710 	RWD:  15.1 	M_RWD:  63.64 	LEN:  68 	EPS:  0.7407
# ITER:  711 	RWD:  57.8 	M_RWD:  63.36 	LEN:  175 	EPS:  0.7406
# ITER:  712 	RWD:  18.6 	M_RWD:  62.7 	LEN:  41 	EPS:  0.7405
# ITER:  713 	RWD:  19.1 	M_RWD:  62.22 	LEN:  37 	EPS:  0.7405
# ITER:  714 	RWD:  57.2 	M_RWD:  61.88 	LEN:  160 	EPS:  0.7403
# ITER:  715 	RWD:  14.8 	M_RWD:  61.17 	LEN:  50 	EPS:  0.7403
# ITER:  716 	RWD:  17.0 	M_RWD:  61.18 	LEN:  47 	EPS:  0.7402
# ITER:  717 	RWD:  19.3 	M_RWD:  60.39 	LEN:  39 	EPS:  0.7402
# ITER:  718 	RWD:  65.3 	M_RWD:  60.86 	LEN:  552 	EPS:  0.7396
# ITER:  719 	RWD:  59.9 	M_RWD:  61.27 	LEN:  744 	EPS:  0.7389
# ITER:  720 	RWD:  56.05 	M_RWD:  61.3 	LEN:  221 	EPS:  0.7387
# ITER:  721 	RWD:  19.45 	M_RWD:  60.81 	LEN:  33 	EPS:  0.7386
# ITER:  722 	RWD:  126.7 	M_RWD:  61.46 	LEN:  277 	EPS:  0.7384
# ITER:  723 	RWD:  74.95 	M_RWD:  61.64 	LEN:  183 	EPS:  0.7382
# ITER:  724 	RWD:  67.0 	M_RWD:  61.75 	LEN:  212 	EPS:  0.738
# ITER:  725 	RWD:  71.1 	M_RWD:  61.9 	LEN:  217 	EPS:  0.7377
# ITER:  726 	RWD:  58.2 	M_RWD:  61.91 	LEN:  99 	EPS:  0.7376
# ITER:  727 	RWD:  16.35 	M_RWD:  61.46 	LEN:  56 	EPS:  0.7376
# ITER:  728 	RWD:  92.9 	M_RWD:  61.18 	LEN:  1047 	EPS:  0.7365
# ITER:  729 	RWD:  65.8 	M_RWD:  61.68 	LEN:  401 	EPS:  0.7361
# ITER:  730 	RWD:  66.4 	M_RWD:  61.81 	LEN:  673 	EPS:  0.7355
# ITER:  731 	RWD:  17.4 	M_RWD:  61.07 	LEN:  45 	EPS:  0.7354
# ITER:  732 	RWD:  19.4 	M_RWD:  61.11 	LEN:  43 	EPS:  0.7354
# ITER:  733 	RWD:  63.85 	M_RWD:  61.21 	LEN:  1943 	EPS:  0.7334
# ITER:  734 	RWD:  18.75 	M_RWD:  60.72 	LEN:  35 	EPS:  0.7334
# ITER:  735 	RWD:  55.1 	M_RWD:  61.09 	LEN:  151 	EPS:  0.7333
# ITER:  736 	RWD:  108.6 	M_RWD:  61.29 	LEN:  1137 	EPS:  0.7321
# ITER:  737 	RWD:  81.55 	M_RWD:  61.41 	LEN:  1063 	EPS:  0.7311
# ITER:  738 	RWD:  67.65 	M_RWD:  61.42 	LEN:  546 	EPS:  0.7305
# ITER:  739 	RWD:  72.7 	M_RWD:  61.55 	LEN:  333 	EPS:  0.7302
# ITER:  740 	RWD:  134.75 	M_RWD:  62.33 	LEN:  669 	EPS:  0.7295
# ITER:  741 	RWD:  58.9 	M_RWD:  62.34 	LEN:  527 	EPS:  0.729
# ITER:  742 	RWD:  64.15 	M_RWD:  61.79 	LEN:  327 	EPS:  0.7287
# ITER:  743 	RWD:  18.1 	M_RWD:  61.8 	LEN:  57 	EPS:  0.7286
# ITER:  744 	RWD:  56.9 	M_RWD:  62.2 	LEN:  241 	EPS:  0.7284
# ...
# ITER:  3873 	RWD:  160.2 	M_RWD:  143.63 	LEN:  262 	EPS:  0.0821
# ITER:  3874 	RWD:  164.65 	M_RWD:  143.02 	LEN:  228 	EPS:  0.0818
# ITER:  3875 	RWD:  179.25 	M_RWD:  142.96 	LEN:  200 	EPS:  0.0816
# ITER:  3876 	RWD:  162.9 	M_RWD:  142.94 	LEN:  205 	EPS:  0.0814
# ITER:  3877 	RWD:  165.6 	M_RWD:  142.83 	LEN:  183 	EPS:  0.0813
# ITER:  3878 	RWD:  327.7 	M_RWD:  143.85 	LEN:  923 	EPS:  0.0803
# ITER:  3879 	RWD:  165.45 	M_RWD:  144.75 	LEN:  163 	EPS:  0.0802
# ITER:  3880 	RWD:  125.95 	M_RWD:  144.47 	LEN:  211 	EPS:  0.08
# ITER:  3881 	RWD:  147.8 	M_RWD:  144.06 	LEN:  416 	EPS:  0.0795
# ITER:  3882 	RWD:  179.55 	M_RWD:  144.37 	LEN:  231 	EPS:  0.0793
# ITER:  3883 	RWD:  98.6 	M_RWD:  144.78 	LEN:  131 	EPS:  0.0792
# ITER:  3884 	RWD:  68.1 	M_RWD:  144.91 	LEN:  112 	EPS:  0.0791
# ITER:  3885 	RWD:  97.2 	M_RWD:  145.69 	LEN:  232 	EPS:  0.0788
# ITER:  3886 	RWD:  324.4 	M_RWD:  147.29 	LEN:  1337 	EPS:  0.0775
# ITER:  3887 	RWD:  180.0 	M_RWD:  147.45 	LEN:  203 	EPS:  0.0773
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3888 	RWD:  228.05 	M_RWD:  148.41 	LEN:  356 	EPS:  0.0769
# ITER:  3889 	RWD:  160.8 	M_RWD:  148.37 	LEN:  425 	EPS:  0.0765
# ITER:  3890 	RWD:  69.1 	M_RWD:  145.97 	LEN:  114 	EPS:  0.0764
# ITER:  3891 	RWD:  55.75 	M_RWD:  144.9 	LEN:  59 	EPS:  0.0763
# ITER:  3892 	RWD:  166.3 	M_RWD:  144.25 	LEN:  267 	EPS:  0.0761
# ITER:  3893 	RWD:  163.2 	M_RWD:  144.62 	LEN:  192 	EPS:  0.0759
# ITER:  3894 	RWD:  76.45 	M_RWD:  143.85 	LEN:  134 	EPS:  0.0758
# ITER:  3895 	RWD:  153.15 	M_RWD:  144.82 	LEN:  152 	EPS:  0.0756
# ITER:  3896 	RWD:  218.5 	M_RWD:  145.35 	LEN:  983 	EPS:  0.0746
# ITER:  3897 	RWD:  228.9 	M_RWD:  145.82 	LEN:  419 	EPS:  0.0742
# ITER:  3898 	RWD:  184.55 	M_RWD:  145.83 	LEN:  219 	EPS:  0.074
# ITER:  3899 	RWD:  59.45 	M_RWD:  145.08 	LEN:  75 	EPS:  0.0739
# ITER:  3900 	RWD:  60.3 	M_RWD:  145.12 	LEN:  75 	EPS:  0.0738
# ITER:  3901 	RWD:  51.1 	M_RWD:  145.42 	LEN:  110 	EPS:  0.0737
# ITER:  3902 	RWD:  171.25 	M_RWD:  144.93 	LEN:  215 	EPS:  0.0735
# ITER:  3903 	RWD:  252.25 	M_RWD:  146.18 	LEN:  677 	EPS:  0.0728
# ITER:  3904 	RWD:  164.75 	M_RWD:  146.53 	LEN:  242 	EPS:  0.0726
# ITER:  3905 	RWD:  230.8 	M_RWD:  148.28 	LEN:  350 	EPS:  0.0722
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3906 	RWD:  222.2 	M_RWD:  148.97 	LEN:  675 	EPS:  0.0716
# ITER:  3907 	RWD:  168.05 	M_RWD:  148.77 	LEN:  191 	EPS:  0.0714
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3908 	RWD:  251.45 	M_RWD:  149.46 	LEN:  698 	EPS:  0.0707
# ITER:  3909 	RWD:  183.65 	M_RWD:  149.44 	LEN:  199 	EPS:  0.0705
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3910 	RWD:  181.65 	M_RWD:  150.5 	LEN:  194 	EPS:  0.0703
# ITER:  3911 	RWD:  75.4 	M_RWD:  149.64 	LEN:  123 	EPS:  0.0702
# ITER:  3912 	RWD:  99.9 	M_RWD:  149.28 	LEN:  102 	EPS:  0.0701
# ITER:  3913 	RWD:  19.4 	M_RWD:  148.48 	LEN:  27 	EPS:  0.07
# ITER:  3914 	RWD:  189.2 	M_RWD:  149.38 	LEN:  184 	EPS:  0.0698
# ITER:  3915 	RWD:  162.7 	M_RWD:  149.13 	LEN:  227 	EPS:  0.0696
# ITER:  3916 	RWD:  59.65 	M_RWD:  148.11 	LEN:  69 	EPS:  0.0695
# ITER:  3917 	RWD:  340.75 	M_RWD:  150.14 	LEN:  434 	EPS:  0.0691
# ITER:  3918 	RWD:  127.2 	M_RWD:  149.64 	LEN:  152 	EPS:  0.069
# ITER:  3919 	RWD:  182.65 	M_RWD:  149.98 	LEN:  213 	EPS:  0.0687
# ITER:  3920 	RWD:  229.6 	M_RWD:  150.4 	LEN:  330 	EPS:  0.0684
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3921 	RWD:  166.8 	M_RWD:  150.71 	LEN:  154 	EPS:  0.0683
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3922 	RWD:  265.65 	M_RWD:  152.79 	LEN:  321 	EPS:  0.0679
# ITER:  3923 	RWD:  53.25 	M_RWD:  151.45 	LEN:  68 	EPS:  0.0679
# ITER:  3924 	RWD:  153.95 	M_RWD:  151.5 	LEN:  144 	EPS:  0.0677
# ITER:  3925 	RWD:  19.3 	M_RWD:  150.03 	LEN:  28 	EPS:  0.0677
# ITER:  3926 	RWD:  230.65 	M_RWD:  150.7 	LEN:  392 	EPS:  0.0673
# ITER:  3927 	RWD:  185.35 	M_RWD:  151.56 	LEN:  194 	EPS:  0.0671
# ITER:  3928 	RWD:  163.75 	M_RWD:  152.21 	LEN:  166 	EPS:  0.0669
# ITER:  3929 	RWD:  165.25 	M_RWD:  152.47 	LEN:  165 	EPS:  0.0668
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3930 	RWD:  229.2 	M_RWD:  152.88 	LEN:  467 	EPS:  0.0663
# ITER:  3931 	RWD:  123.6 	M_RWD:  152.6 	LEN:  179 	EPS:  0.0661
# ITER:  3932 	RWD:  154.95 	M_RWD:  152.35 	LEN:  146 	EPS:  0.066
# ITER:  3933 	RWD:  98.6 	M_RWD:  152.78 	LEN:  124 	EPS:  0.0659
# [INFO] Saving model
# [INFO] Saving model
# ITER:  3934 	RWD:  215.3 	M_RWD:  153.29 	LEN:  1099 	EPS:  0.0648
# ITER:  3935 	RWD:  18.35 	M_RWD:  151.62 	LEN:  34 	EPS:  0.0647
# ITER:  3936 	RWD:  56.9 	M_RWD:  148.85 	LEN:  64 	EPS:  0.0647
# ITER:  3937 	RWD:  165.85 	M_RWD:  148.68 	LEN:  167 	EPS:  0.0645
# ITER:  3938 	RWD:  60.15 	M_RWD:  148.2 	LEN:  68 	EPS:  0.0644
# ITER:  3939 	RWD:  76.2 	M_RWD:  147.07 	LEN:  184 	EPS:  0.0643
# ITER:  3940 	RWD:  167.6 	M_RWD:  148.58 	LEN:  175 	EPS:  0.0641
# ITER:  3941 	RWD:  181.7 	M_RWD:  149.72 	LEN:  211 	EPS:  0.0639
# ITER:  3942 	RWD:  18.7 	M_RWD:  148.28 	LEN:  30 	EPS:  0.0638
# ITER:  3943 	RWD:  163.3 	M_RWD:  148.81 	LEN:  225 	EPS:  0.0636
# ITER:  3944 	RWD:  164.6 	M_RWD:  148.67 	LEN:  160 	EPS:  0.0635
# ITER:  3945 	RWD:  173.8 	M_RWD:  149.42 	LEN:  269 	EPS:  0.0632
# ITER:  3946 	RWD:  97.6 	M_RWD:  149.83 	LEN:  107 	EPS:  0.0631
# ITER:  3947 	RWD:  187.9 	M_RWD:  149.4 	LEN:  198 	EPS:  0.0629
# ITER:  3948 	RWD:  59.3 	M_RWD:  148.61 	LEN:  70 	EPS:  0.0628
# ITER:  3949 	RWD:  129.0 	M_RWD:  148.05 	LEN:  126 	EPS:  0.0627
# ITER:  3950 	RWD:  99.0 	M_RWD:  148.49 	LEN:  115 	EPS:  0.0626
# ITER:  3951 	RWD:  60.3 	M_RWD:  148.09 	LEN:  74 	EPS:  0.0625
# ITER:  3952 	RWD:  51.85 	M_RWD:  148.02 	LEN:  398 	EPS:  0.0621
# ITER:  3953 	RWD:  60.4 	M_RWD:  148.06 	LEN:  68 	EPS:  0.062
# ITER:  3954 	RWD:  59.3 	M_RWD:  146.6 	LEN:  121 	EPS:  0.0619
# ITER:  3955 	RWD:  173.4 	M_RWD:  146.53 	LEN:  278 	EPS:  0.0616
# ITER:  3956 	RWD:  203.4 	M_RWD:  147.64 	LEN:  1587 	EPS:  0.06
# ITER:  3957 	RWD:  163.6 	M_RWD:  149.08 	LEN:  166 	EPS:  0.0599
# ITER:  3958 	RWD:  18.85 	M_RWD:  148.56 	LEN:  28 	EPS:  0.0598
# ITER:  3959 	RWD:  165.65 	M_RWD:  148.41 	LEN:  178 	EPS:  0.0597
# ITER:  3960 	RWD:  169.0 	M_RWD:  149.1 	LEN:  170 	EPS:  0.0595
# ITER:  3961 	RWD:  179.4 	M_RWD:  149.32 	LEN:  198 	EPS:  0.0593
# ITER:  3962 	RWD:  161.95 	M_RWD:  148.65 	LEN:  361 	EPS:  0.0589
# ITER:  3963 	RWD:  177.95 	M_RWD:  148.63 	LEN:  191 	EPS:  0.0587
# ITER:  3964 	RWD:  58.35 	M_RWD:  147.69 	LEN:  134 	EPS:  0.0586
# ITER:  3965 	RWD:  56.35 	M_RWD:  146.73 	LEN:  59 	EPS:  0.0586
# ITER:  3966 	RWD:  77.0 	M_RWD:  146.76 	LEN:  144 	EPS:  0.0584
# ITER:  3967 	RWD:  138.6 	M_RWD:  146.49 	LEN:  139 	EPS:  0.0583
# ITER:  3968 	RWD:  162.45 	M_RWD:  146.84 	LEN:  381 	EPS:  0.0579
# ITER:  3969 	RWD:  163.85 	M_RWD:  146.26 	LEN:  160 	EPS:  0.0577
# ITER:  3970 	RWD:  69.9 	M_RWD:  144.45 	LEN:  100 	EPS:  0.0576
# ITER:  3971 	RWD:  69.6 	M_RWD:  143.88 	LEN:  149 	EPS:  0.0575
# ITER:  3972 	RWD:  55.75 	M_RWD:  142.78 	LEN:  58 	EPS:  0.0574
# ITER:  3973 	RWD:  233.35 	M_RWD:  143.51 	LEN:  231 	EPS:  0.0572
# ITER:  3974 	RWD:  55.05 	M_RWD:  142.41 	LEN:  86 	EPS:  0.0571
# ITER:  3975 	RWD:  128.7 	M_RWD:  141.91 	LEN:  195 	EPS:  0.0569
# ITER:  3976 	RWD:  165.2 	M_RWD:  141.93 	LEN:  221 	EPS:  0.0567
# ITER:  3977 	RWD:  99.45 	M_RWD:  141.27 	LEN:  117 	EPS:  0.0566
# ITER:  3978 	RWD:  76.05 	M_RWD:  138.75 	LEN:  126 	EPS:  0.0564
# ITER:  3979 	RWD:  138.75 	M_RWD:  138.49 	LEN:  188 	EPS:  0.0563
# ITER:  3980 	RWD:  128.85 	M_RWD:  138.52 	LEN:  129 	EPS:  0.0561
# ITER:  3981 	RWD:  164.5 	M_RWD:  138.68 	LEN:  173 	EPS:  0.056
# ITER:  3982 	RWD:  69.95 	M_RWD:  137.59 	LEN:  181 	EPS:  0.0558
# ITER:  3983 	RWD:  215.85 	M_RWD:  138.76 	LEN:  1039 	EPS:  0.0547
# ITER:  3984 	RWD:  74.15 	M_RWD:  138.82 	LEN:  170 	EPS:  0.0546
# ITER:  3985 	RWD:  165.45 	M_RWD:  139.5 	LEN:  162 	EPS:  0.0544
# ITER:  3986 	RWD:  163.15 	M_RWD:  137.89 	LEN:  160 	EPS:  0.0542
# ITER:  3987 	RWD:  139.15 	M_RWD:  137.48 	LEN:  177 	EPS:  0.0541
# ITER:  3988 	RWD:  188.35 	M_RWD:  137.08 	LEN:  204 	EPS:  0.0539
# ITER:  3989 	RWD:  57.15 	M_RWD:  136.05 	LEN:  72 	EPS:  0.0538
# ITER:  3990 	RWD:  183.3 	M_RWD:  137.19 	LEN:  228 	EPS:  0.0536
# ITER:  3991 	RWD:  244.0 	M_RWD:  139.07 	LEN:  2005 	EPS:  0.0516
# ITER:  3992 	RWD:  58.3 	M_RWD:  137.99 	LEN:  68 	EPS:  0.0515
# ITER:  3993 	RWD:  56.4 	M_RWD:  136.92 	LEN:  80 	EPS:  0.0514
# ITER:  3994 	RWD:  51.2 	M_RWD:  136.67 	LEN:  163 	EPS:  0.0512
# ITER:  3995 	RWD:  189.5 	M_RWD:  137.04 	LEN:  179 	EPS:  0.0511
# ITER:  3996 	RWD:  98.15 	M_RWD:  135.83 	LEN:  103 	EPS:  0.051
# ITER:  3997 	RWD:  163.05 	M_RWD:  135.17 	LEN:  408 	EPS:  0.0506
# ITER:  3998 	RWD:  58.2 	M_RWD:  133.91 	LEN:  68 	EPS:  0.0505
# ITER:  3999 	RWD:  164.0 	M_RWD:  134.96 	LEN:  202 	EPS:  0.0503
# ITER:  4000 	RWD:  180.6 	M_RWD:  136.16 	LEN:  203 	EPS:  0.0501
# ITER:  4001 	RWD:  232.55 	M_RWD:  137.97 	LEN:  270 	EPS:  0.0498
# ITER:  4002 	RWD:  73.7 	M_RWD:  137.0 	LEN:  134 	EPS:  0.0497
# ITER:  4003 	RWD:  129.2 	M_RWD:  135.77 	LEN:  166 	EPS:  0.0495
# ITER:  4004 	RWD:  189.0 	M_RWD:  136.01 	LEN:  183 	EPS:  0.0493
# ITER:  4005 	RWD:  164.2 	M_RWD:  135.34 	LEN:  175 	EPS:  0.0492
# ITER:  4006 	RWD:  261.4 	M_RWD:  135.74 	LEN:  265 	EPS:  0.0489
# ITER:  4007 	RWD:  97.45 	M_RWD:  135.03 	LEN:  113 	EPS:  0.0488
# ITER:  4008 	RWD:  239.3 	M_RWD:  134.91 	LEN:  2005 	EPS:  0.0468
# ITER:  4009 	RWD:  225.95 	M_RWD:  135.33 	LEN:  262 	EPS:  0.0465
# ITER:  4010 	RWD:  176.0 	M_RWD:  135.27 	LEN:  446 	EPS:  0.0461
# ITER:  4011 	RWD:  152.45 	M_RWD:  136.04 	LEN:  219 	EPS:  0.0458
# ITER:  4012 	RWD:  128.2 	M_RWD:  136.33 	LEN:  122 	EPS:  0.0457
# ITER:  4013 	RWD:  152.25 	M_RWD:  137.66 	LEN:  188 	EPS:  0.0455
# ITER:  4014 	RWD:  99.0 	M_RWD:  136.75 	LEN:  192 	EPS:  0.0453
# ITER:  4015 	RWD:  173.8 	M_RWD:  136.87 	LEN:  246 	EPS:  0.0451
# ITER:  4016 	RWD:  58.0 	M_RWD:  136.85 	LEN:  73 	EPS:  0.045
# ITER:  4017 	RWD:  187.95 	M_RWD:  135.32 	LEN:  216 	EPS:  0.0448
# ITER:  4018 	RWD:  179.5 	M_RWD:  135.84 	LEN:  236 	EPS:  0.0446
# ITER:  4019 	RWD:  164.8 	M_RWD:  135.67 	LEN:  209 	EPS:  0.0444
# ITER:  4020 	RWD:  137.3 	M_RWD:  134.74 	LEN:  141 	EPS:  0.0442
# ITER:  4021 	RWD:  75.75 	M_RWD:  133.83 	LEN:  140 	EPS:  0.0441
# ITER:  4022 	RWD:  155.65 	M_RWD:  132.73 	LEN:  1101 	EPS:  0.043
# ITER:  4023 	RWD:  149.1 	M_RWD:  133.69 	LEN:  215 	EPS:  0.0428
# ITER:  4024 	RWD:  54.1 	M_RWD:  132.69 	LEN:  99 	EPS:  0.0427
# ITER:  4025 	RWD:  99.4 	M_RWD:  133.49 	LEN:  166 	EPS:  0.0425
# ITER:  4026 	RWD:  126.3 	M_RWD:  132.45 	LEN:  137 	EPS:  0.0424
# ITER:  4027 	RWD:  129.1 	M_RWD:  131.89 	LEN:  128 	EPS:  0.0422
# ITER:  4028 	RWD:  187.0 	M_RWD:  132.12 	LEN:  203 	EPS:  0.042
# ITER:  4029 	RWD:  171.85 	M_RWD:  132.19 	LEN:  190 	EPS:  0.0418
# ITER:  4030 	RWD:  164.95 	M_RWD:  131.54 	LEN:  162 	EPS:  0.0417
# ITER:  4031 	RWD:  169.45 	M_RWD:  132.0 	LEN:  325 	EPS:  0.0414
# ITER:  4032 	RWD:  215.75 	M_RWD:  132.61 	LEN:  1049 	EPS:  0.0403
# ITER:  4033 	RWD:  214.75 	M_RWD:  133.77 	LEN:  1050 	EPS:  0.0393
# ITER:  4034 	RWD:  179.05 	M_RWD:  133.41 	LEN:  187 	EPS:  0.0391
# ITER:  4035 	RWD:  149.55 	M_RWD:  134.72 	LEN:  217 	EPS:  0.0389
# ITER:  4036 	RWD:  138.85 	M_RWD:  135.54 	LEN:  131 	EPS:  0.0387
# ITER:  4037 	RWD:  256.55 	M_RWD:  136.45 	LEN:  533 	EPS:  0.0382
# ITER:  4038 	RWD:  125.65 	M_RWD:  137.1 	LEN:  163 	EPS:  0.038
# ITER:  4039 	RWD:  151.0 	M_RWD:  137.85 	LEN:  220 	EPS:  0.0378
# ITER:  4040 	RWD:  100.3 	M_RWD:  137.18 	LEN:  100 	EPS:  0.0377
# ITER:  4041 	RWD:  127.15 	M_RWD:  136.63 	LEN:  140 	EPS:  0.0376
# ITER:  4042 	RWD:  150.8 	M_RWD:  137.95 	LEN:  172 	EPS:  0.0374
# ITER:  4043 	RWD:  157.3 	M_RWD:  137.89 	LEN:  1571 	EPS:  0.0358
# ITER:  4044 	RWD:  177.1 	M_RWD:  138.02 	LEN:  202 	EPS:  0.0356
# ITER:  4045 	RWD:  167.55 	M_RWD:  137.95 	LEN:  154 	EPS:  0.0355
# ITER:  4046 	RWD:  224.6 	M_RWD:  139.22 	LEN:  578 	EPS:  0.0349
# ITER:  4047 	RWD:  149.85 	M_RWD:  138.84 	LEN:  196 	EPS:  0.0347
# ITER:  4048 	RWD:  168.85 	M_RWD:  139.94 	LEN:  709 	EPS:  0.034
# ITER:  4049 	RWD:  98.0 	M_RWD:  139.63 	LEN:  109 	EPS:  0.0339
# ITER:  4050 	RWD:  187.1 	M_RWD:  140.51 	LEN:  241 	EPS:  0.0336
# ITER:  4051 	RWD:  55.9 	M_RWD:  140.47 	LEN:  68 	EPS:  0.0336
# ITER:  4052 	RWD:  148.05 	M_RWD:  141.43 	LEN:  222 	EPS:  0.0333
# ITER:  4053 	RWD:  164.65 	M_RWD:  142.47 	LEN:  158 	EPS:  0.0332
# ITER:  4054 	RWD:  153.25 	M_RWD:  143.41 	LEN:  155 	EPS:  0.033
# ITER:  4055 	RWD:  230.8 	M_RWD:  143.98 	LEN:  384 	EPS:  0.0326
# ITER:  4056 	RWD:  152.2 	M_RWD:  143.47 	LEN:  202 	EPS:  0.0324
# ITER:  4057 	RWD:  152.4 	M_RWD:  143.36 	LEN:  205 	EPS:  0.0322
# ITER:  4058 	RWD:  182.05 	M_RWD:  144.99 	LEN:  178 	EPS:  0.0321
# ITER:  4059 	RWD:  169.6 	M_RWD:  145.03 	LEN:  244 	EPS:  0.0318
# ITER:  4060 	RWD:  163.7 	M_RWD:  144.98 	LEN:  169 	EPS:  0.0317
# ITER:  4061 	RWD:  76.2 	M_RWD:  143.95 	LEN:  159 	EPS:  0.0315
# ITER:  4062 	RWD:  159.8 	M_RWD:  143.93 	LEN:  1360 	EPS:  0.0301
# ITER:  4063 	RWD:  231.0 	M_RWD:  144.46 	LEN:  264 	EPS:  0.0299
# ITER:  4064 	RWD:  126.4 	M_RWD:  145.14 	LEN:  125 	EPS:  0.0297
# ITER:  4065 	RWD:  187.85 	M_RWD:  146.45 	LEN:  186 	EPS:  0.0296
# ITER:  4066 	RWD:  177.95 	M_RWD:  147.46 	LEN:  305 	EPS:  0.0293
# ITER:  4067 	RWD:  57.9 	M_RWD:  146.65 	LEN:  69 	EPS:  0.0292
# ITER:  4068 	RWD:  165.2 	M_RWD:  146.68 	LEN:  179 	EPS:  0.029
# ITER:  4069 	RWD:  76.5 	M_RWD:  145.81 	LEN:  142 	EPS:  0.0289
# ITER:  4070 	RWD:  226.7 	M_RWD:  147.38 	LEN:  507 	EPS:  0.0284
# ITER:  4071 	RWD:  175.9 	M_RWD:  148.44 	LEN:  221 	EPS:  0.0281
# ITER:  4072 	RWD:  163.05 	M_RWD:  149.51 	LEN:  173 	EPS:  0.028
# ITER:  4073 	RWD:  333.3 	M_RWD:  150.51 	LEN:  844 	EPS:  0.0271
# ITER:  4074 	RWD:  163.2 	M_RWD:  151.59 	LEN:  161 	EPS:  0.027
# ITER:  4075 	RWD:  17.35 	M_RWD:  150.48 	LEN:  35 	EPS:  0.0269
# ITER:  4076 	RWD:  217.0 	M_RWD:  151.0 	LEN:  1218 	EPS:  0.0257
# ITER:  4077 	RWD:  71.95 	M_RWD:  150.72 	LEN:  132 	EPS:  0.0256
# ITER:  4078 	RWD:  151.05 	M_RWD:  151.47 	LEN:  174 	EPS:  0.0254
# ITER:  4079 	RWD:  233.15 	M_RWD:  152.42 	LEN:  285 	EPS:  0.0251
# ITER:  4080 	RWD:  57.05 	M_RWD:  151.7 	LEN:  71 	EPS:  0.025
# ITER:  4081 	RWD:  181.55 	M_RWD:  151.87 	LEN:  177 	EPS:  0.0249
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4082 	RWD:  217.9 	M_RWD:  153.35 	LEN:  1059 	EPS:  0.0238
# ITER:  4083 	RWD:  66.1 	M_RWD:  151.85 	LEN:  92 	EPS:  0.0237
# ITER:  4084 	RWD:  127.4 	M_RWD:  152.38 	LEN:  134 	EPS:  0.0236
# ITER:  4085 	RWD:  230.1 	M_RWD:  153.03 	LEN:  386 	EPS:  0.0232
# ITER:  4086 	RWD:  186.05 	M_RWD:  153.26 	LEN:  181 	EPS:  0.023
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4087 	RWD:  170.9 	M_RWD:  153.58 	LEN:  223 	EPS:  0.0228
# ITER:  4088 	RWD:  180.5 	M_RWD:  153.5 	LEN:  197 	EPS:  0.0226
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4089 	RWD:  228.55 	M_RWD:  155.21 	LEN:  412 	EPS:  0.0222
# ITER:  4090 	RWD:  169.7 	M_RWD:  155.08 	LEN:  220 	EPS:  0.022
# ITER:  4091 	RWD:  151.6 	M_RWD:  154.15 	LEN:  232 	EPS:  0.0217
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4092 	RWD:  205.95 	M_RWD:  155.63 	LEN:  1567 	EPS:  0.0202
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4093 	RWD:  185.9 	M_RWD:  156.92 	LEN:  190 	EPS:  0.02
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4094 	RWD:  186.3 	M_RWD:  158.27 	LEN:  181 	EPS:  0.0198
# ITER:  4095 	RWD:  167.2 	M_RWD:  158.05 	LEN:  161 	EPS:  0.0196
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4096 	RWD:  170.85 	M_RWD:  158.78 	LEN:  969 	EPS:  0.0187
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4097 	RWD:  231.0 	M_RWD:  159.46 	LEN:  254 	EPS:  0.0184
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4098 	RWD:  228.8 	M_RWD:  161.16 	LEN:  420 	EPS:  0.018
# [INFO] Saving model
# [INFO] Saving model
# ITER:  4099 	RWD:  323.2 	M_RWD:  162.76 	LEN:  1123 	EPS:  0.0169
# ITER:  4100 	RWD:  165.15 	M_RWD:  162.6 	LEN:  166 	EPS:  0.0167
# ITER:  4101 	RWD:  129.35 	M_RWD:  161.57 	LEN:  124 	EPS:  0.0166
# ITER:  4102 	RWD:  153.5 	M_RWD:  162.37 	LEN:  147 	EPS:  0.0164
# ITER:  4103 	RWD:  162.6 	M_RWD:  162.7 	LEN:  170 	EPS:  0.0163

# %%
# ## MANUAL SAVE
# agent.save_models()

# train_metadata = {
#     'episode_n': len(mean_rewards),
#     'best_reward': best_reward,
#     'mean_rewards': mean_rewards,
#     'episode_rewards': episode_rewards, 
#     'episode_lengths': episode_lengths,
#     'episode_epsilons': episode_epsilons
# }
# T.save(train_metadata, (ROOT+"/train_metadata.pkl"))
# Out:
# [INFO] Saving model
# [INFO] Saving model

# %% [markdown]
# ## **Testing**

# %%
env_name = 'SuperMarioBros-1-4-v0'
env = make_env(env_name)
ROOT = './weights'

agent = DuelingDDQNAgent(observation_shape=env.observation_space.shape,
                         n_actions=env.action_space.n,
                         lr=1e-4,
                         gamma=0.99,
                         epsilon=1.0,
                         epsilon_min=0.01,
                         epsilon_decay=1e-6,
                         beta=0.4,
                         beta_max=1.0,
                         beta_increment=6e-5,
                         mem_size=1,
                         mem_alpha=0.6,
                         batch_size=1,
                         Q_TARGET_replace_interval=1,
                         initial_exploration_steps = 1,
                         algo_name='DuelingDDQN',
                         env_name=env_name,
                         model_dir=ROOT)

agent.load_models(cpu=True)
# Out:
# [INFO] Loading model
# [INFO] Loading model
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
train_metadata = T.load((ROOT+"/train_metadata-1-4.pkl"))
print(train_metadata.keys())
print("ITER:\t",train_metadata['episode_n'])
print("BEST:\t",train_metadata['best_reward'])

plt.plot(train_metadata['mean_rewards'])
# Out:
# dict_keys(['episode_n', 'best_reward', 'mean_rewards', 'episode_rewards', 'episode_lengths', 'episode_epsilons'])
# ITER:	 3545
# BEST:	 149.5049999999998

# %%
with T.no_grad():
    total_reward, total_moves = 0,0
    done = False
    observation = env.reset()

    while not done:
        time.sleep(0.05)
        env.render()

        # e_GREEDY ACTION
        action = agent.get_action(observation, greedy=True)
        observation_, reward, done, _ = env.step(action)

        total_reward += reward
        total_moves += 1

        observation = observation_
    print("RWD: ",total_reward,"\tLEN: ",total_moves)
    # env.close()
# Out:
# RWD:  251.89999999999947 	LEN:  202
